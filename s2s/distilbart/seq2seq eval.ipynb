# %%
import logging
import wandb
import torch.multiprocessing
torch.multiprocessing.set_sharing_strategy('file_system')
import numpy as np
import fastwer

import pandas as pd
from simpletransformers.seq2seq import (
    Seq2SeqModel,
    Seq2SeqArgs,
)


logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

model_args = Seq2SeqArgs()
model_args.num_train_epochs = 15
# model_args.no_save = True
model_args.evaluate_generated_text = True
model_args.evaluate_during_training = True
model_args.evaluate_during_training_verbose = False
model_args.tensorboard_dir = "runs"
model_args.max_length = 200
model_args.train_batch_size=25
model_args.overwrite_output_dir=True
model_args.wandb_project = "cs224u"
model_args.eval_batch_size = 25

# Initialize model
model = Seq2SeqModel(
    encoder_decoder_type="bart",
    encoder_decoder_name="./outputs/best_model",
    args=model_args,
    use_cuda=True,
)

# model = Seq2SeqModel(encoder_decoder_type="bart", encoder_decoder_name="./outputs/best_model", args=model_args, use_cuda=True,)

# model = Seq2SeqModel(
#     encoder_type="bert",
#     encoder_name="bert-base-uncased",
#     decoder_name="bert-base-uncased",
#     args=model_args,
#     use_cuda=True,
# )


def count_matches(labels, preds):
    return sum(
        [
            1 if label == pred else 0
            for label, pred in zip(labels, preds)
        ]
    )

def get_wer(labels, preds):
    return np.mean(
        [
            fastwer.score_sent(pred, label)
            for label, pred in zip(labels, preds)
        ]
    )

# %%
test_df = pd.read_pickle("test.pkl")

# %%
model.predict(
        [
            "Hee walks dogks", "Hai my precous boi", "tteko", "e trade often coing sides with other traes", "he kepts extensive nodes on a cosing playurs"
        ]
    )
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Generating outputs', max=1.0, style=ProgressStyle(descrip…
# ['She walks dogs..... she walks dogs',
#  "Hai my cousin, you.Hai's cousin.",
#  'What do you think?...”',
#  'They trade often co-operate with other tribes.',
#  'He keeps extensive nodes on a competing platform..']

# %%
testlist = test_df['input_text'].tolist()
len(testlist)
# Out:
# 2000

# %%
outlist = model.predict(testlist)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Generating outputs', max=80.0, style=ProgressStyle(descri…

# %%
outlist
# Out:
# ['Hanno wrote of his expedition in Stel.',
#  "Little Eilidh's death for many other families in this country is sad in many ways.",
#  'You have the ability to fog on the song "The Her".',
#  'His major priority is ungariocolomications, a central to communications and software development.',
#  'The mansion also has a marriage office...',
#  'Hannicopters can land and lunch on its deck.',
#  'Thirteen of the series have been collected into train paper backs.',
#  'Jane and Ros nearly fell overboard... and Jane and Ros.',
#  "We'd like to seek clear weather...",
#  'The stream near Ritchie is still called Ridewater River, near Wyndham, Vermont.',
#  'It is located near the school on Church Lane.',
#  "The show was eventually staged for four weeks at O'Valley House in Cambridge.",
#  'Abraham Ham has also played for the Atlanta Falcons and Arizona Cardinals.',
#  "The parts were running against each other, so they didn't have to go through rounds.",
#  'The burden for this cost is transferred to the department of finance.',
#  'Along with other album tracks, "The Best Album" is the album\'s third studio album.',
#  'This book was written in Arabic... ',
#  'All I was doing was turning it...',
#  "I'm all the stop about having an accident.",
#  'They were always so good...“',
#  'They are like net-like rappels to be used for deep freeze compression.',
#  'It is also the last stop before crossing the Waverham Parkway.',
#  'Paco is buried in the northeast corner of the American city of Fortune.',
#  'The cappuccino rages no longer exist.',
#  'Reliable, please, please... M.',
#  'Alternative risk assessment is one of the main tools used in science and engineering.',
#  'There are other forces changing the direction of the earth.',
#  'After this time, it was the president of the "Hitterabar" Southeastern Water Company.',
#  'It is the county seat of Salford County.',
#  "As the twenty-twenty-twin's career faltered with the advent of top-secretes.",
#  'The megadrive version was released exclusively in Europe.',
#  'The title track lyric says "Soul" "Are you alive or not?',
#  'They however can be stored with a built-in extension.',
#  'The bottom of the shoe had a gold trim.',
#  'They now carry crimes which can be avoided..',
#  '"You Bo" was released as an emotional single, but also failed to find success.',
#  'He recognized the Council of the High Dunes and the High Dam Rich.',
#  'He is buried in a massed and cross-country cemetery in Osbourne, County, Virginia.',
#  'Martin Martin is an Englishman in New York.',
#  'Non-reluctant excitation occurs when the incoming radiation promotes a core electron to the continuum.',
#  'The Bolivian restaurants serves traditional French food using modern techniques.',
#  "The district's sales sold the building to the province.",
#  'The original concrete station building has been demolished..',
#  'Thus, the president was served... ',
#  'He appeared on a number of recordings both as a sideman and a sideter.',
#  'They need to keep junkish out of the market.',
#  'Combine City and Eliza and Jurdonin capital city of Athens, this is verreally gains.',
#  'The turlanddrop was stored in a closet.',
#  "He promoted Badger's album and comments on the album in the United States and the Netherlands.",
#  'For example, they are not used for being the main security forces.',
#  'He played in the National Hockey League with the Toronto Panthers.',
#  'Our promise is Missouri State University is its newest capital campus.',
#  'Baths originating from fears in distress and from drowning are also commonplace.',
#  'Junior racher and shoe hanger were sitting next to the table.',
#  "That's the main idea... that's the only idea.",
#  'With a back of March, it was a dream come true.',
#  'She made her living in the village. and is married and not in the country.',
#  "The reaction is counter-exactly the same as the other's, with the same reaction.",
#  "He represented Quinton's Land and played a starring role in the Irish County Championship scene at First Class Relegation.",
#  'Before going into acting, he worked at the film studio, where he was a dramatist.',
#  'The market is the largest in the United States, the largest economy.',
#  'In the third round, he stopped leaving the team, which continued with other pre-show decisions.',
#  'And the layout design in its current form have made major changes through the years.',
#  'Then Admiral Alexander read the bullet, calling it the "back-side".',
#  "McQuack's North American headquarters are in Atlanta.",
#  'These two games at home against the Wigan Athletic team was separate games played under normal conditions.',
#  'It was a subsidiary part of the Chances and the Royal Navy.',
#  'The area was named after the town of Kilrea in Ireland.',
#  'He is an orange-hanging figure in a black-haired parrot.',
#  'The bros are packed on chocolate, next to the next clique locks of an expensive table.',
#  'The amateur compilots learn quick, quick, low-lotto, with the zero.',
#  'It is the first game in the Sunroser Series.',
#  'Unfortunately, all the moss on the computer is frying the system.',
#  'Nepa-Shikishi Primary School is one of the schools in the district.',
#  'In the same article, Gulldenived the claim he condone prostitution.',
#  'During her literary career she has written several short stories and essays.',
#  'Sorel was born in Aridia, Georgia.',
#  'The older of the two is known as "Porro\'s" or "Porcine".',
#  'It was free to sell in the supermarket, being of "good" quality.',
#  'It is the second-best carol version in British history.',
#  'It attracts a lot of anglers, coming out fishing mahash fish.',
#  'He was born on a farm near Bowery, New South Wales.',
#  'So where are the language boarders?..',
#  'It is popular known as the "Miracle of Everything".',
#  'Starfighters are equipped with different weaponry which can be highly effective in certain missions.',
#  'The agreement level reflects individual differences in general concern for social harmony.',
#  'On the lower back there are three capering red barns.',
#  'Eventually enough were disallowed from this action..',
#  'And the towns are named after them. and they are named in honour.',
#  'The old age could get a new of mums.',
#  "What's the matter?... I'm sure.",
#  'He made a mess of it... he did.',
#  'She has her slightly bobbled head...',
#  'However, when it comes to the naturism, one had no conscious control over it.',
#  'However, this method of securing security is the one for intra-party transfer.',
#  'This kind of convection is referred to as "percivalization" simply "spike".',
#  "It's normal to have these symptoms...",
#  'In most cases, it performs more or less to the same number of seats.',
#  'There are many famous African and African-American descended people living in London.',
#  'There are two Methodist churches on campus in London and one Methodist church.',
#  'She was born in Saint Denis, Leicestershire, to Maryock Berans.',
#  'It is believed to have created a unique "B" for the side of the wall.',
#  'I think this field is the highest of the concentration bases and facilities.',
#  'The current version of the standard standard is a non-standard.',
#  'Merules of Barrow were not permitted by the Royal Navy.',
#  'Big man\'s found in the sinking body of a cylinder, called a "soul of the soul".',
#  'The town is named after the name "Tataba" at the north-south corner of Alibia.',
#  'This was after meeting with Sychoan Alistair Houghman.',
#  'The lease duty expired... the lease was cancelled.',
#  'Is this some sort of test?...',
#  'The brass notes were perfectly flawless, but slightly distorted by the altor.',
#  'A bit of a foundation of business learning..',
#  'He was a right-wing conservative in his class.',
#  'The town centre had its own shopping centre..',
#  'And this was a wonderful surprise to the whole world.',
#  'Hence celebrations and the party were held in the same place.',
#  "Worth's of course, the Shankshenkredumption Fund is funded by the Second Seven Fund.",
#  'Its edges are wide with four-inch spikes.',
#  'He was to star in the film...',
#  'The slabs are to the side which we are in a natural cage.',
#  'Bbonmender the astamite position was from a remote island.',
#  'His family has operated a farm in Leir County for three generations.',
#  'He concludes that with his death the galaxy has become a dangerous place.',
#  'This is an alternate form of regulation for the Giza-Sultanate unit.',
#  'It was an owling cart... it was an ode.',
#  'One side does not make a difference...',
#  'He was the son of President and Vice-President Serenza Sorenstav.',
#  'These rivers are the hubs of the Hephortus and the Cocdowno.',
#  'He was an unpopular king, and preferred his for military rule.',
#  'Take care of the paces, and the pears will take care of themselves.',
#  'They are used in manufacturing of active paste for the dacrystal process.',
#  'There are several bus boarding stands available at the airport.',
#  'The son of Alistair is born in Nactin.',
#  'And then things happened very quickly... and then.',
#  'During the while one of the main players had been playing at the stadium, Pangina and the stadium.',
#  'Caviar press coverage is available for six months.',
#  'The municipality comprises the towns of Cocker, Rockingham, Newbury, and Renigam L.',
#  'Generally, the lollipop would not excertate the characteristics of the object.',
#  'What were you talking about??.',
#  'I generally sit indoors and listen to the wireless.',
#  'How did you produce this?...How did he produce this.',
#  'It is half-length, covered by bodies of the seven healers of the Nile River.',
#  'That enraged Suspecian the next day after Lincon had been assassinated.',
#  'The Security Council section lists member states and their central banks that manage their own currencies.',
#  'The Metro Metro subway line runs through the park along its west edge.',
#  'The union is known worldwide for its opposition to same-sex marriage.',
#  'This text addresses a basicology of the game universe.',
#  "Guilder's hopes that the team would win the tournament were shattered.",
#  'It is a fairly certain line they save the mine.',
#  "We're all home, I am right here.",
#  'Back was also subsequently used as a military arm in the Ottoman Empire.',
#  "At his sisters' side, they're charming women.",
#  'He wrote the book on "Sport" with Margaret Verne titled "Batsman".',
#  'The company pays free landscaped programmers that earn royalties from their creations.',
#  'Similar to a tenas son, Dadi played the piano solo of the album "Produce Pain".',
#  'He was decorated with the Order of the Thirteen C of the Cavalry in Oortburg.',
#  'The village of Cotonayo is named after the village.',
#  'The capital city is also called "Cebanada".',
#  'And this won\'t happen again."The sperter\'s.',
#  'That year he was out of action and left after two seasons.',
#  'It is the only international terminal in the United States.',
#  'McMuris is a member of the Congress of the socialist party.',
#  'He lived in Raleigh, North Carolina, United States.',
#  'Digital manipulation relies on no single technique, but instead synchronizes possession from multiple inputs.',
#  'Access cyclists and cyclists are effectively banned from using the tunnel.',
#  'The party has a strong anti-Islamic stance.',
#  'He was defeated by Durban in the November election.',
#  'Compared to those of interior Alabama, Mississippi, and Tennessee.',
#  'This is now the sight of the humor packer offices in Sydney.',
#  'Several notable naval engagements occurred off the Hoeft Fission Station.',
#  'Telephone names are more important than the test specimen.',
#  'He would ofen read the bible while cutting.',
#  'Out of the report came the archery of the Russian hand.',
#  'Some speak the high-definition of books at an international level.',
#  'What is the best way to medecision?',
#  'He looked like one who had passed through an uncomfortable doorway or two.',
#  'He had no idea what in the future would be.',
#  'The old village is still distinctly visible surrounding the old White Village Church.',
#  'He was educated at Harrow School and Trinity College, Cambridge.',
#  'This name came to be used for the river as well.',
#  'Sectors are generally said in municipal board meetings or zonal.',
#  'Briand and his deputies.. ',
#  'They were issued by the single standard instill shield shield in stall.',
#  "A longer, bigger screen credit card is don't see a screen like a laptop.",
#  'He was born of history of genious engineers and the trained mathematicians.',
#  'Butcaver station has a single station, black from serving by direct traffic.',
#  'The old village was abandoned and all of its buildings were deemed dangerous.',
#  'Like it has a distinct culture... ',
#  'Its name is named after the French poet Charles de Gaulois.',
#  'It was his last chance....',
#  'These programs are primarily designed to promote socially responsible management and operating systems.',
#  'The bill is still ten times higher than the average weight, so the play too makes contact with the liquid surface.',
#  'In classical French, family-owned albums cannot accure in succession.',
#  'He tended to gravitate in collage and metamorphism.',
#  'Of its listed costs, these are expected to be free.',
#  'Tyler Liddis sings live guitar and she plays as a bassist playing to the keys.',
#  'In his very season, "Miscow" was critically acclaimed.',
#  'The record fell in the following year, almost a month later.',
#  'The journal constitution declined to publish "Miscine Review".',
#  'This becomes prohibitive, veritably large, because of the cost of energy.',
#  'The forth cometh is awarded two years term.',
#  "Some of the list lists at the highest level in women's and men's entertainment.",
#  'It does not fully support the position of the Secretary of State for the State Department of Education.',
#  'Blackwood later became a partner and the business partner with Shar.',
#  'Morton was sentenced to the death of not the magistrate.',
#  'These two have equal stats...”',
#  '"Can you see two masts from the opposite side?" the boy replied.',
#  'In many cases, the main market is located in London.',
#  'Sauphine was such a close friend.',
#  'These rare levels make it a better buffer between puzzles and action.',
#  'His legs could be called serviceable...',
#  'He was the eldest son of Major David Smith and his wife, Harriett.',
#  'The project was being planned, but it was eventually scrapped due to financial concerns.',
#  'This film is ultimate press, the pesit-less base of the film.',
#  'I got out and broke it up...',
#  'After graduate school and after graduate school, Elborta is a graduate student.',
#  "Bobby Cluc was created by Carey O'Sullivan and Mike Kempish.",
#  'Malyharrish should not be mistaken for a large air and aircraft engineering company.',
#  'In doing so, the boy... in doing so.',
#  'His primary focus has been on one issue: "How long is it?"',
#  'The popularity of education chairs on the board has been praised.',
#  'Burlincontry not long ago is named for the town.',
#  'Glise Manning also played this role in "Living Life" series.',
#  'Tremayarda was standing in a hard-cote part of a fountain fountain running.',
#  'At the time of her death, the alchemist had begun her second career.',
#  'She was the flag bearer with two opposing sides.',
#  'He has been renamed as Best of the World.',
#  'Being able to do other, if you want, subject matter keeps me going in school.',
#  'Every silider has its own technical and financial banking system.',
#  'The bat and the bat boy promoted the persm-nears team.',
#  "I'm thinking about a paner on the table.",
#  'My dog plays no... I do.',
#  'At the end, the team is effectively entirely under-funded.',
#  'A church will be built and his grave sight.',
#  'The one hundred largest towns are listed...',
#  'Dewall faced Republican National Army personnel in the Junior Collection.',
#  'She is a national championship in trueloyalty for the artistic waterbirths ceremonies.',
#  'The game requires the player to use two modes of play.',
#  'Under the scorboard both in a vending stall with a vending machine, with shelves and other things available.',
#  "Henderson's eyes are expected to begin to appear on the same day.",
#  'He entered the island, and the wizard began to appear in the light, disappearing.',
#  'The mind is now closed, it is now primarily a source for a cultural culture.',
#  'Unless you are wise, the main source of ratings in the newspaper is "Bolot" Post-Dynasty.',
#  'He also expressed his support for a moderate social security reform.',
#  'Shanks attended the University of the Netherlands from where he received his low degree.',
#  'A number of his employees in Paskany, Wisconsin.',
#  'He was a plock-sitter with the Parogomat programme.',
#  'The castle still exists today, and the town itself remains.',
#  'The date of the college is unknown...',
#  'Harrison is an unusual three bedroom family home.',
#  'The state plack is used on governmental buildings and embassies.',
#  'Then they spat on her and hated her..',
#  'Besides this was first of the first of its kind on the turn.',
#  'Fo was the son of Cornan C. M. N. Nangana.',
#  'The album features the past compilation album "Running Out of My Mind".',
#  'Some versions also can be engineered with batter stairs.',
#  'Wait until that day... and then wait.',
#  'In these works, Glass used repetitive structures off a contemporary style.',
#  'He was a member of the moderate Republican Main Street Partnership.',
#  'Their size and shape are regular, because they are not perfect pheres.',
#  'Today the Vellow Slex is again manufactured in France.',
#  "You're a great writer, I told you.",
#  'The current holders are Alastair Arkinson in Henry, Buckinghamshire.',
#  'The album was a highly acclaimed biographical album.',
#  'The official opposition was the Liberal Party led by Alexandra Meyer.',
#  'And the tournament is under way, with Bad as Trav during the first round.',
#  'But be back eight years later...“',
#  'Wondos layer crook in to check for food.',
#  'There are numerous international holders in the district..',
#  'The team spent the winter in the Flemish village of Bournemouth, Rhode Island.',
#  'The routes for the new campus included technical institute, colleges and schools.',
#  'The concern is that the problem may present one more risk of further damage.',
#  'These computer viruses are usually detected on devices like computer systems or mobile devices.',
#  'He attended the wedding ceremony...  he attended the ceremony.',
#  'The program imitates normal Shabat\'s "Bobbygrammy Camp".',
#  'The team\'s mascots are a tea-cumer and her sister and sister, the "Cocker".',
#  'It may be the source of an emergency signal from the vicinity.',
#  'The exterior scenes were shot in Broken Hill, in Wrexham, Wales, and Sydney, Australia.',
#  'Native American settlers quickly replaced the native population..',
#  'The most significant of the early designs was the "Heroine" Erlineer.',
#  'For example, one could rely on certificate authorities or a warrant of trust.',
#  'That night, the crew at the ship can no longer bear the burden of the crew.',
#  'Three people you know are playing in the water at something.',
#  'Two guys in a white shirt with plans behind their neck are carrying on as they move along.',
#  'A bike rider riding down a street dressed in green and blackjack',
#  'A little boy on a red shirt in blue.',
#  'This model is furthered in higher levels of undergraduate studies.',
#  'The Monday night flight lived up to its billing.',
#  "Alchemy thus remains one of the world's most underdeveloped fields.",
#  'Copalooba has a tropical and arid desert climate.',
#  'You can do this even faster... I can do it even faster!',
#  'The reeds are unservedly, but are still a significant part of the structurally stable structure.',
#  'Building the engagement narrative supends the image of the event itself.',
#  'It is also a recreation venue for evening concerts.',
#  'God the eagles are far from the ground.',
#  'They told me and called me back...',
#  'It is on the island of St. E. Egan.',
#  'She was born in London, London, and raised in New York.',
#  'The narrow and winding road north of Mombadishe was especially affected.',
#  '"Because I\'ll give you a good scream play or sincere apology," said Mombt.',
#  'Hence city is similar to the natural ability to produce a city.',
#  'Cranconused stock markets to make financial trading decisions.',
#  'The seat is local...“The seat was empty.',
#  'This memorial cross was displayed at the National Museum of Military History in Vienna.',
#  'The Kolkata family lived in modest conditions, with father was a miller and clockmaker.',
#  'Also, there is a pub opening at the station main entrance.',
#  'Co-Hockey also urged the country to become a society of light-hearted citizens.',
#  'Many of these paints feature hamatask, hence the name of the company.',
#  'She served as an editor of many international professional journals.',
#  'Mortett and clarislav Lloyd Rogers.',
#  'The most important commercially growing species is ocra.',
#  'It is also known as a perferer and a consummate as a consummant.',
#  'Sirconfession agreements, however, only the most successful can be held of such agreements.',
#  'The general direction of the party is a conservative consensus.',
#  'In addition, gaining in has become a dictive to many gamers.',
#  'Mak and I walked together up the hill to the hotel.',
#  'Whether he leaned forward and shook his head with a smile.',
#  'He is a very popular name..."',
#  'Sence in cultivation was associated with the discovery of a gold ore pit.',
#  'He introduced a law that directly challenged the discriminatory practices imposed by the local authorities.',
#  'Minar began his career onstructing polbulties with friends from China.',
#  'They counselled the women amongst the men.',
#  'Some in the media are credited with their success.',
#  'Several roads town centre cemeteries had to be relocated.',
#  'Thomas Crumwell was the first editor of "Maxine".',
#  'Furthermore, it has an extensive relationship with clubs Western and Midia Business.',
#  "The child was immediately given to Lewis' family.",
#  'The city of Tenerife, where the construction has been made to serve.',
#  'Also, Reneist describes it as a "modern version" of black and white image.',
#  "He pointed out the flaw in his brother's argument.",
#  'Is that program proprietary software, or is it open source?',
#  'A former mayor is giving a speech on Friday.',
#  'Only so-called "quiriable" data can be efficiently stable stats in single parameter parameters.',
#  'The iron guard was forced out of the government.',
#  "The third vacancy was created after Aldeman Rosie's death.",
#  'The grips can be the wood or imitation mother of hearl handles.',
#  "In this series, Hawgan's source of problems for the locals.",
#  'There is one three car parking area for this station.',
#  "Why don't you play and let's meet them?",
#  'Here at home, he met with success, establishing a medical practice that prospered quickly.',
#  'The two bricks are laid by course...',
#  'Hoor of the British settlements in Kolkata were completely abandoned.',
#  'Thrives is known as "Celia" and "Uropological" Wig.',
#  'Counquay is played over gravel, but the plaques graded and mowed with age.',
#  'The development is due to be completed within seven years.',
#  'It lies within the city of Charlemagne.',
#  'England and Wales are two countries where the Pyramids grew up and Marsque.',
#  'It was created by trauma, the process of torture.',
#  'Not one noticed her...“Not one?',
#  'We will not take up the offer early in the story.',
#  'Increment the order if you require more than just one item.',
#  'Along with Carock, the boy returned sixteen miles to the kingdom.',
#  'The best program was the morning show with Adrian Williams and Sophie Morison.',
#  'You could not have trusted the animal...',
#  'He left his family, saw they could quickly develop and construct the resources them.',
#  'It was covered in black and white at the time.',
#  'Rise is located at the second location of the Dark Isle of Arras.',
#  'The album "Snapping" has fans in Ontario, Ontario.',
#  'Misty Poms on the land around the mine.',
#  'These iscothes were used for near-commercial trade of cotton wheat and apples.',
#  "He was educated at Mount St Mary's College in Pink Hill, Berkshire.",
#  'There is a large gap or a hole between the cheek teeth from the insides.',
#  'Canada requires tax deduction at source for payments of compensation by employees.',
#  'But even finding the centre of gravity of this sphere accurately was difficult.',
#  'Iro River runs slightly west of Kolkata.',
#  'Her hair is white, with one or other mombular symbol.',
#  'Wondemakers are laughing at home play at their stadium.',
#  'Oussey Mainman and General Prescriptor soonin filled the position.',
#  'Since then she has also acquired a substantial stake in Fairfax Media.',
#  'But this said means independence from other institutions..',
#  'Kousherem is located in the Salem School District and has a low elementary school.',
#  'They were used to treat cancer in psychotropic medicine.',
#  'Down the Hill is another regional administration that is merged with just out of control.',
#  'Elli is the surname of Christinna and Altina.',
#  'When the planet is in two worlds, it is described as "the largest heist".',
#  'Rainful is very frequent in this part, and it often changes quickly.',
#  'Little is known of this period and his life.',
#  'It is due to the sudden combination of light, vision and pressure.',
#  'Johns Crips supports him, placing it in an explicit classification.',
#  'Margaret Carter preferred with her teacher to get better grades.',
#  'The alarm panel should have both a buzzer and indicator light.',
#  'The Australian bolt-dog is the biggest adbostost as a species of dog.',
#  'A side from his father is idle was one of the best broadcasts by play broadcaster Jan Robson.',
#  'They have two sons: North America, North Australia, Australia, and Taiwan.',
#  'The National Park is located west of Asperges on the southern coast.',
#  'The Court of Appeal denied this reasoning and upheld the conviction.',
#  'Saint Thomas also has many factories for food processing and electrical equipment.',
#  'The title also appears as a line in one year of Lovel.',
#  'In his youth, Mike was a golfer.',
#  'In all other instances, the most popular song was "Penny" L.',
#  'It has been described as "sadder than a war in Yemen".',
#  'An entrepreneur is a example of business planning..',
#  'Playing the album on the air may be played live or recorded.',
#  'Shakes the line back to the front..',
#  'The closing theme of the programme was "A Challenge".',
#  'The school operates under the supervision of the Junior Academy.',
#  'He confessed, he went to prison...',
#  'Conoly undertook a tour of Germany, Austria and Hungary before starting at Oxford University.',
#  'They are not currently performing...They are.',
#  'He ever returned to school... he never returned.',
#  'The water flows through most of the tracks of the rider, wait, Smith.',
#  'The rooms are designed to accommodate four women each.',
#  'These drugs may have systemic side-effects including diabetes and pencethetitis.',
#  'Four pedestrians the fairgrounds remain free of charge.',
#  'Yeah is also extensively cultivated throughout the city..',
#  'Others do not behave as clearly like monacelabic dip thongs.',
#  'The island is northwest of the Settle Beach State Reserve.',
#  'He studied naval medicine in the United States..',
#  'Initially she worked with Andy Garro arranging his escape over the Pyramids.',
#  'It was named after the composer Paul Scholberg.',
#  'It is not a life-long tradition of the old church.',
#  'Stone is still being used for gates of the house.',
#  'This song featured in "Stout and a bit of a joke".',
#  'They do not create and experience that in the world they want.',
#  'General aviation engineers trained for the Soviet Union and the United States Army made it their main aircraft.',
#  'In some population, such as those of the "T" population, the "E" is considered a "E".',
#  'He is right with consensus to play the first round at the tournament.',
#  'There is also a popular online advertising...',
#  'You need to practice this discipline carefully if you want to succeed.',
#  'She went over and played two games...',
#  'There were no fash was tied...',
#  'But his work is available for viewing online..',
#  'He was the older brother of American novelist Tom Biddle.',
#  'Bowing the house codes for cartoisky as some dark-spirited, religious, spiritual touch.',
#  'Tom arrives at Cairns House to find her hand cut to the wall.',
#  'Thus, subsequently, Stuckney began work on his new Washington hotel.',
#  'It may also be associated with nervous symptoms of anxiety, depression and other psychological disorders.',
#  'The capitol could be five inches of a water-filled building.',
#  'One feature of the reference line is the use of the Treble Lidol-Soracian-Mariatic-Woffers.',
#  'The airport has two public facilities, one for international and one for domestic traffic.',
#  'Sheep and Lillian Florence, and the Turof series of games and movies.',
#  'Sylvedon School that Pupils sent to is respected, a very different way from her families.',
#  'Worthbound would be extremely difficult to return.',
#  'It is a carnivorous fish that feeds on velorous fish.',
#  'Outrage from all sides had caused the train to roll over after the crash.',
#  'It is supported with the conservative school of farm policy.',
#  'The first was somewhere in England, its grand life.',
#  'Once both were dead, however, their successors became embroiled in war.',
#  'Return of ministry following the third round veries widely among individuals.',
#  'He last played professionally for Nottinghamshire County..',
#  'At that time the two schools existed separately, with two separate commanding officers.',
#  'For the first time, they are allowed to play for a team.',
#  '"I\'m the only one with this," the Englishman answered.',
#  'Morley Loves the Leveau Park distinct wood bins.',
#  'The police are investigating whether they are acting against the American.',
#  'However, the school now holds this ranking..',
#  "Cebbie's wife, Tessa, thinks she's pregnant with a baby.",
#  'They have documents of anti-nationalist opposition against nation socialism.',
#  "Prior to his House assignment, more and more in Congress President Obama's administration.",
#  'We need to wait a minute or two. I do.',
#  "Futnam can't help the city.",
#  'Located in the area, it used more businesses.',
#  'His most well-known works were the open-air dances, which would drop pantomime from all sides around.',
#  'There are two attempts to establish a garrison in the area.',
#  'The north-south-south border is the border.',
#  'And I have a liking for the rust and must and must have been there.',
#  'Ronde Foxes inhabit... Ronde.',
#  'Doing an open district, she said the placement was relevant to the project.',
#  'In an online survey, it does not show how it works.',
#  'Thopos are used primarily for sanitization and clogging.',
#  'The president has the right to reorganize the bureaucratic process.',
#  'If Goodman had turned the role down, the film would not have been made.',
#  'The family moved and spread across the village of Ballycliff, near the border with Ireland.',
#  'Some infinities will also not display any cap inside throwing objects.',
#  'Teleglegation and learning are the only learning experience.',
#  'The infrontals spanic all the lines are almost identical.',
#  'Man who is subject to an education examination are drafted into the Army through the Army Reserve.',
#  'The Argyll and Bergerville community consists of a small, elderly community.',
#  'A litar super is effective for the treatment of bacterial infections in esi.',
#  'The television was named for Federicambreier as "Wish-Traveller Poet" and "Wet-Tortor".',
#  'Other upgrades include a new ceiling, new lighting and a new carpet board.',
#  'The region has many villages in other parts of the United States.',
#  'These brown water omissions altered water aspiration patterns.',
#  'Yorkshire with ten and the last few years were introduced.',
#  'Littleell is known as Little Lell..',
#  'The girl is joined in her quest by Frisbee, and so, is born.',
#  'As a result, Al-Mareis has replaced Girmis as head coach of the club.',
#  '"We shall be careful," he said. "I think he\'d.',
#  "She's up there again, talking about it.",
#  "I'm really a big beast, you know.",
#  'She was the only woman with him, your young friend, away.',
#  "What's what's what got done?..",
#  "I'd give a thousand if a few producers reviewed this.",
#  'The fighting had become intermittent...“',
#  "except if you have Father's blessing and with it this.",
#  'The album quickly spread throughout the punk community, earning the bandome nation-wide recognition.',
#  'Flexon was born and raised in Kennet and Connecticut.',
#  'They just had no idea about that...',
#  'He was elected president of the New Zealander First Party when Doug Wulerton resigned.',
#  'It has two serving ticket offices and uses a ticket-selling system.',
#  'The truly remarkable feature of the book is its dizzying, surreal drawings.',
#  'They have two daughters, Michelle and Jessica..',
#  'The gardeners opened to the public every day of the year, except Christmas.',
#  "It was Min's office that oversaw the technical exchange agreement, an extra capital with Westinghouse.",
#  "His father, C. C. O. Hanson, was first cousin of Eric Hanson's father.",
#  'Prior to this, the "H" station aired radio coverage of "Radio Canada" with locally aired images.',
#  'Vickett played college football at the University of Southern California.',
#  'He was a councillor at the School for American Football.',
#  'General consensus is that the current situation is very similar to that of the Soviet Union.',
#  'A collection of books, books, magazines, and other material.',
#  'This was the third of the four colonies that the colony is located today.',
#  'The sound truck all but featured R&O music.',
#  'The village of Flose Springs is served by the Union County Service.',
#  'It flows north west to receive the River Strels River at the town of Ross River.',
#  'You have to read many novels. How?',
#  'He activated the system the second day of the session.',
#  'Collins named him because she disliked him...',
#  'Wolley also participated in the opening of several branches in Austria, Germany.',
#  'It was therefore decided between local authorities from already ancient time.',
#  'Soon we were on board flying to Alaska..',
#  'The school has continued to twin with the Woodgate School in Ningham.',
#  'The city is named for the ideal of political unity.',
#  'Oh my sisters. Oh my sisters!..',
#  'Emphasis is placed on those discoveries affecting human life.',
#  'Dorcked Miro wrote a quote distraced of the melaty language and philosophy.',
#  'A good amount of time was spent on the project.',
#  'It was based on a hatchet housed in a tool pouch.',
#  'There has been some confusion over when the original "No" quote was released.',
#  'Frootic cities in Dorset are placed under provincial government.',
#  'Overwhelmingly, it offers a simple, straightforward travel and package-hogging.',
#  'Four years later, she took him to the dentist.',
#  'As a result, the code is quipped with anti-social behaviour in the system in electronic fashion.',
#  'He attended Dudley Middle School....',
#  'The explosion raises a large amount of moisture-laden air from lower altitudes.',
#  'Oriente is originally named the School of Commerce and domestic science.',
#  'He was driving with his daughter, Anna, who survived the crash.',
#  'Once he sensed that you were prepared, he was thoroughly professional.',
#  'The company also has a division called "nowservice" and "now games".',
#  'Hangarsh has minimal rest facilities on its side.',
#  'The parish consists of four hamlets: Aldermills, Upper Wood and Lower Wood.',
#  "Bobby Vasion and Mike O'Brien look on as axes lead from the entry.",
#  'Then the red button button is listed in descriptions of Marian County Cenpeth.',
#  'The extent of military education in military personnel is unclear.',
#  'Please free the political prisoners or it will be a sore death for all of you.',
#  'It is divided into two halves by the city of Myhat, Tomadi.',
#  'The issue with this conclusion is determining the correctness of the inter-laced operations.',
#  'Originally, there was considerable difference in the authority files of the different libraries.',
#  'He holds her captive, revamps her and cuts out her tongue.',
#  'Fro-era port systems to stylize was gradually replaced by a writing slate.',
#  'extremely high-speed aircraft can easily rotate and make mid-air collisions.',
#  'The combination of both animal pictures and one figurete has developed.',
#  "Training home and children's technology...“",
#  'It also offers scholarships and awards to its members.',
#  'From bicycle parts, she lists off bicycle parts manufacturing companies.',
#  'It is one of the earliest examples of near-life synchronised synchronised.',
#  'Each level is divided out with a case to sole and some possible groups.',
#  'The horse and bagi was the premarital version of the "Mondonderry" for the Kides.',
#  'Dog Coded of the challenges include jumping, jumping, and collecting items from others.',
#  "I was just a writer, so I'm not in any hurry.",
#  'The new version has eleven new features...',
#  '"Going bowling the same day as you want," he said.',
#  'I was complete surprise, however, there was no surprise.',
#  'Say what he has got to say...',
#  'The unincorporated community of Smilth Landing is located in the town.',
#  'All songs written by Zappa must otherwise be noted.',
#  'The following books "Migran Herner" also appear in the British Library catalogue.',
#  "The mayor's term of office was also increased from one year to two.",
#  'There is reception here.....',
#  'And how at the directions were they?..',
#  'Sooner many of you will be walking along Broadway.',
#  'Sush in the middle of a muffling environment.',
#  'He was looking somewhere in the sky and tucked up the right wing.',
#  'Saint Laurent is home to the Canadian Real World Museum.',
#  'The street begins in the north as Albion Road north at Walkley Road.',
#  'They were reported to be one of the most rebellious tribes at the time.',
#  'Spatial Huddersfield College next door to the east.',
#  'All the tracks, including the main track, are in Stranraer, Canada.',
#  'This batch typically runs on until well into the second round.',
#  'During his tenure, he faced several financial problems caused by the recession.',
#  'Computer tasks are fairly easy to use and requires some careful use.',
#  'The box of these rare items is now considered a collectors item.',
#  'Feral solicelli contained more than half a tonne of consumable liquid.',
#  'Many women not actually sit in the crowd for sake.',
#  'It will come back. It will come..',
#  'The letter is usually referred to as "Bridgend".',
#  'He has also been the patron of the racehorse used throughout the country.',
#  'The device developed was the first tetelike system.',
#  'The sand store is on down duty, or a nice and by men.',
#  'Towns could use the term "Sis the Queen" to further praise Bodes as a beautiful partner.',
#  'He travelled through Shanghai, Hong Kong, Singapore and India, working as he went.',
#  'The entire album track is also something to be recorded and recorded.',
#  'Irenely loved the lizards because I love my people.',
#  'Following that season, he went out of juniors.',
#  'This participation of Carlors Artistic Team Scotland first date.',
#  'His flute was a novelty to say the same thing.',
#  'The principal seat of the lords of Toulon was at Clough.',
#  'To the west, their well-known contemporary style was the Monicry Strelge.',
#  'Frieshahn factory in eastern Germany..',
#  'It refers to a line concourse of four or five feet.',
#  'There is no reason to worry about these issues.',
#  'The new engine modes distolabor...',
#  'There are only a limited number of churches in Denmark.',
#  "It's now the water arriving at the lake, Floo and Loo.",
#  'The man who hosted the event was consistent with previous requisitions in the region.',
#  'She claimed the journalist did not know what she was talking about.',
#  'The Maple Phyllic poems written and published later.',
#  'From men on the win was called "Tobodon".',
#  'Ginset does not appear as a barrier in the motion picture.',
#  'The band enjoyed much regional and some national success and released three albums.',
#  'The Foundation supports educational, medical, diagnostic testing and social therapy programs.',
#  'The lyrics make reference to murder and torture, while other themes include supernatural fantasy.',
#  'A cloud with a single bullet appears from the west and destroys the ring.',
#  "The city's forests also exist in the Sarshas and Prandia districts.",
#  'In the mountains main base of operations was Morana Army Infantry Battalion, the Confederate forces.',
#  "Jefferson's original rough draft is on exhibit in a library of Congress.",
#  'The county seat is Cumbria...',
#  'The first person to enter the room was Amanda Foster.',
#  'This problem arose this time this year, because the main opponent was the Texas Longhorns.',
#  'However, not all government agencies are opposed to axing corporate tax credits from everything regulations.',
#  'Who is the author of "Hussein\'s The Soul of the World" magazine?',
#  'Bels are the headquarters of the "M" medical school in the city of Cushendu.',
#  'Harrison is the manager of the Nighting Ward in the United States.',
#  'It is a small portion....',
#  'Bittarian and conservative politicians were particularly active in the Federation process.',
#  'This includes three B-52s of the patchy attack helicopter.',
#  'They spite this to Africa on matchday. their matches.',
#  'He is considered to be the founder of medical education in Poland.',
#  'Language codes in many languages are highly important to the language.',
#  'Mayday for no reason is a wary old biker, there are many.',
#  'While the President would be elected by a majority of the delegates.',
#  'He was silent for the best part of a minute.',
#  'Sharper activities included participation in local end-of-year programming and free tech issues.',
#  'Gorrea reportedly was forced to retaliate against Russia and most Sarsps in retaliation.',
#  'The sackond section is the site of a very new form of crisis.',
#  'After Burns, the band was reconcluded with the revision of the organization and theology.',
#  'He would have regretted it, but he had come.',
#  'Grixson had seated himself under the lamp and was unable to bring a pencave.',
#  'It is currently used mostly for uppermenters.',
#  'The algorithm, along with its pac pacemaker, was implemented by T-Fakage Works.',
#  'The late Latin American historians will engrish the "spiritual" in the more.',
#  'The few printed prescriptions are available, in some cases, while still in circulation.',
#  "Thank you, you've been very generous and kind.",
#  "I'm going to side right... I'm going.",
#  'Please help me search the bank in a television shop.',
#  "For a while I've got there...",
#  'This farm is farmed by the Great Flanders and the British Isles.',
#  'At the camon foca point superposition of both focus-like images occurs.',
#  'It is illegal thinking of it is prohibited..',
#  '"I just decided to natchet write normal songs," recalled Steveenson.',
#  'Parts of the road are close to fishing or a canoeing lake.',
#  'She has appeared on the cover of several Philippine magazines.',
#  "Darren's work has been referenced and copied many other artists in different ways.",
#  'Cortnoden was the terminus of the slate for "Boltonaline".',
#  'He also played school disco with his own band, K-Ceclops.',
#  'The type of housing was still usually built in the same year.',
#  'Homer Hernheim was a member for the lost Abbey of the Magdalene.',
#  'All of these "Ship\'s Side" stories were created by two men, Daffy.',
#  'Nowhere in modern China, the country was occupied by the Japanese.',
#  'The hamper had only just arrived the night before they started selling the bilet.',
#  'It is the centre of Camping County..',
#  'She is known as the leader of the "Ulster Road" in the western region.',
#  'He was widely praised for his leadership of the movement.',
#  'More recent works include racing money for the winner against Roger DeSareman.',
#  'However, it has not been widely used by documentary filmmakers.',
#  'She works as an amateur team coach, team trainer and coach.',
#  'A slap or smacker may also be used.',
#  "Neither Kenny or Kenny Dickson's father was the musician and record producer Jim Dickson.",
#  'It was also the first mission of the Luna program.',
#  'Another Irish king can be since he was a drunk.',
#  "This technique is must likely the fastest method if it's correct.",
#  'The shire light-wares are constructed from aluminium and use copper storts.',
#  'However, propelledentes are extremely toxic..',
#  'Sail sank instantly, there were no survivors.',
#  'Their maternal daughter, Carla, was president of the student union at the University.',
#  'The Control and Ettershire has the only undefettered team in team selection.',
#  'There are no permanent fates...“',
#  'From the battlefield, the Jewish army entered Parma and took four press of duty.',
#  'Growthinians and rivines are now widely used by Russian or Ukrainian citizens.',
#  'A disease is an abnormal condition affecting the body of an organism.',
#  'Scuba diving off Seaburn in Wiggo County is extremely popular with tourists and locals.',
#  'The last of the Petro engines was designed by Watson himself.',
#  'Both recordings covered hare, such as the Italian, have Latin, and European languages.',
#  'These are separate tokens, and so will remain as such in the program listing.',
#  'He is also the patron of the town and town of Booga.',
#  'Rebuilding began immediately, and at an impressive pace.',
#  'Olivia Pritzetin has a reputation for designing Moderation, yet that litically restrained buildings.',
#  'Satisfaction for candetation is high in the relevent content.',
#  'These newspapers in "Pep" put their negative attitude on hold and opened up "The Rat I mean Carter".',
#  'The system ran under their respective operating systems without interruption.',
#  'The pens are also a popular option for ticketing, and merchandise promotion.',
#  'Spide needs to change its album, "Less Less" received rave reviews upon its release.',
#  'Heroic achievements in acting remained the norm..',
#  'He also became a member of the Part of the Communist Union.',
#  'One was of Polish descent, and the third was Republican.',
#  'Several different teams were also hired to advise the British on the deployment of Sabotav.',
#  'He was born in Fano, Italy..',
#  'Access in all areas are one in the main shopping area.',
#  'One she must agree to be installed at the temple of the Prophet Muhammad.',
#  'Pipes are the main sources of radio and television.',
#  'To chancely, it has a primary administrative that is non-compliant.',
#  "Primarily, they don't have any china fingers.",
#  'The added pressure of the pressure rose above..',
#  'The collar of the cluck consists of red, white, and blue floral stripes.',
#  'Following a series of buildings and guess where..',
#  "Possymus is seen as the early sign of Scotland's follicles in the fenlands.",
#  'Most petrophy has a considered ancient tradition of the black.',
#  'You will never be able to free the boy who left it.',
#  'Touss is a ten-mile journey to Jamaica.',
#  'She is into the maternal branch of the family, whom she abandoned after the war.',
#  'Sle has also produced several new documentaries..',
#  'The current authority of the Association of Businesses is the Business Development Council.',
#  'As the only witnesses, we do not believe in quantum knowledge.',
#  'The League is an out-spoken supporter of raising funds for mental health research.',
#  'Nuclear simulation team in the United States..',
#  "Or, and I'll be at the Sunday School Christmas dinner in Coronation.",
#  "The schools' standard body is completely diversified.",
#  'Also new for export models was the availability of a tree-peated template.',
#  'Then she stood up...Then she smiled.',
#  'Mebayo is a popular destination for recreational activities.',
#  "We don't need to throw the ball into it.",
#  'The book includes many songs which are connected to the story.',
#  'The player loses the game when the team fails to finish at the top.',
# ...
#  'They were covered with ash, oak and hazel.',
#  'The overlap part is tropped and is held side.',
#  'Motion is decided by judge in both civil and criminal proceedings.',
#  'Differently, however, they have together used characters of established cartoon characters and stock characters.',
#  'Wryn Elementary School was located in Hutchins.',
#  'Economic arguments to gain free trade criticized the assumptions or conclusions of economic theories.',
#  'As to my heart, I belong entirely to the heart of Jesus.',
#  'The girl old lady is married with one side herself.',
#  'This was his first appearance recorded...“',
#  'He played three seasons with the Vancouver Blizzard before retiring from professional hockey.',
#  'It is one of the few remaining convexible "recyclable" models.',
#  'Wimera has been called the mother of Confederation.',
#  "He was instead appointed as chair of the party's election campaign.",
#  'It is the county seat of Pangang County.',
#  'Taylor Miller scored on the third play-off round.',
#  'Initial establishment of the connection was made using contacts names.',
#  'The main mast of a brigand time is the one.',
#  'Six species of botherfly are known to occur on Christmas Island.',
#  'Twittersbrook was founded as a depot on the Central of Georgia Railway.',
#  'Livisians spend most of their time in the south-east of the country.',
#  'Somewhere in the country, the sun would rise again.',
#  'The tear is long... the tear is short.',
#  'Aliens are also an important component of the Turkish economy.',
#  'The bartenders current director is Elizabeth Hanson..',
#  'We later apologized for his remark... ',
#  'He has also written several books, including "Fairytale", "Fantasy", and "Fantastic".',
#  'He is near the river Alazani northwest of the village, and not east of the town centre.',
#  'Otherwise, no render to could occur if the second element contains a voiced observat.',
#  'There is also a public peer charting the "Cheryl" system.',
#  'The video footage in "Sauva" was directed by visual artist John Daley.',
#  'The Netherlands side unexpectedly won the referendum...',
#  'During later live he did not recite his benfica.',
#  'Welley has achieved many other significant to Milton Keynes since its inception.',
#  'Of course, I got out directly and took his arm.',
#  'Liz just took the technical crew to drive the cart which left.',
#  'The council sits in the treasury... ',
#  'The town of Hoe is to the west of the lake.',
#  'See the film placed in May by Nezale and a Canadian filmmaker.',
#  'The wing of the bill, Georgia Russell, slid through the top two brackets.',
#  'A team handball is only available when the low-willing ranges are open to the public.',
#  'Alice also admitted smuggling a bag with his cousins, Ben.',
#  'He was nephew of the iminent humanist Sidney Burns.',
#  'Feu comes from the same school as the under-age students who studied there.',
#  'The town of Porthcawl is second in the county.',
#  'Fas to choose the best option and for the best on the dunes.',
#  'Angry C. C. has played lead guitar.',
#  'Senton extramart is offered in two editions: Waverham and Commonity.',
#  'It premiered on television and was eventually aired on Home Video.',
#  'The full text of the report is available through several websites.',
#  'Many variants of this all-engine have been built.',
#  'In comparison with the standard variation is culled short arm scissers.',
#  'The neighborhoof is larger than the house.',
#  'Prize later served as a vice-president of the United States under President Barack Obama.',
#  'This was followed by another celebration of the festival.',
#  'He knows me and I know you...',
#  'The formation last three years....',
#  'He also competed in the inaugural season of Superleague.',
#  'At the beginning, I came to the end.',
#  'The film poster was a figure running towards a motorbike rider.',
#  'It is the first album on which the band work with producer Scott Litt.',
#  'An ultematum game is a form of hubsticky choice.',
#  'It is grown as an ornamental plant in southern China, and occasionally occasionally as a hedgehoe.',
#  'He was also a member of the Delta chapter, "Tort".',
#  'The song was extensively arranged with hints of both Welsh and Irish bolk music.',
#  'These are known as the arm pits...',
#  'His mother was born in the province...',
#  'It was re-seeded under the Mira Mihlani-Kurumi-Korbi-Kumisawa-Kukum.',
#  'The film was produced by Hausen Press Media Group.',
#  'Yes indeed, and so did the little woman.',
#  'Ordig M. M. was made of iron and hydrogen.',
#  'There are additionally several parks run by Town of San Francisco, California.',
#  'They saw the dissolution of our lives in the natural world.',
#  'After the war, he immediately declined the position of vice-president.',
#  'There are two towns: Soka, Okinawa and Curatir.',
#  'The muscasses and flooded facilities were mostly retroactive.',
#  'The company will come to your aid nine months later to their marriage.',
#  'Huge traytay is a small fish.',
#  'Welsey Cottage was traditionally called "Cecron".',
#  'She is the director of the "Fresh" Midlothian-based food production company Best in America.',
#  'Booth has made the university a major administrative priority for the university.',
#  'It carries her name on all the English alphabet, long and long.',
#  'She is the cousin of Monty...',
#  "No, I'm a dresser...",
#  'Shree was a very promising young woman, she could have done it.',
#  'And now now, the wind was blowing for him.',
#  'They place the colony of Wethers here.',
#  "We're not going to cut your neck..",
#  'When a war begins, the army turns to private combat in a way.',
#  'Boliam one of the main criticisms of the commentariat is entire for the right reasons.',
#  'This county serves the eastern part of the county.',
#  "A commotion consisted of the maintenance's huts for miniskirts and merry-workmen's hacks.",
#  'The name is "Sant" is a combination of their first names "Saint" and "Satsy".',
#  'Hanson, the father of the radio, had not been trained in the production of the radios.',
#  'He is survived by his mother Carol, his daughter Maggie, and daughter Maggie.',
#  'The villages within Burlington Township....',
#  'During his reign, the Law of Upperland was established.',
#  'He also was one of the first female artists to achieve international recognition.',
#  'And, during the course of his election, Kelly fled before the completion of the second term.',
#  'This election was called early in the recurrence of Republican Party counselor Barry Wood.',
#  'Chamole was an outsproved critic of the former Soviet occupation of Lebanon.',
#  "Alabama's rivers are among the most diverse in the world.",
#  'He put land lines open by the end of the year.',
#  'The theatre was opposed for three months to complete the process.',
#  'That year, the company opens stores in Brooklyn and Chicago.',
#  'The car began to be moved by trucks..',
#  "Shush that baby don't you cryy?",
#  'Roose entered the river and sailed about upstream.',
#  'The cockled hering bone is more than in the mouth of a camel.',
#  'Previously these words contain signs that do not have corresponding letters in Mandarin.',
#  "I'm I have running that desk today..",
#  'He decided not to let the situation affect him, but that most people agree.',
#  'It enjoyed moderate success, entering the top forty on the weekly charts.',
#  'Over time, the couple had four more children, although William never won a scholarship.',
#  'He wanted to be a baker...“',
#  'Then three diss me...”“',
#  'This meant he had two wives, as his first marriage was still extended.',
#  'The summit of the band is the fourth day of the backing album.',
#  'These youths were selected to be the board members by the man.',
#  'The other seven places were generally the termined by commune, qualifying in turnaments.',
#  "From Cambridge, regular service runs to London King's Cross.",
#  'Agane Ganedmacher software and was the subject of a lawsuit.',
#  'Asquaker Creek flows through the town to its confluence with the Mohalpah River.',
#  'Then straight on bowles, Aliosas plays in hand attacks with a comparatively high effectiveness.',
#  'Only after they give the tape, they realize what the truth is.',
#  'Race coffee and cacau are the most important crops grown in the area.',
#  'The album also topped the iTunes album chart..',
#  'Some journalists have even created their own websites, though with some difficulties.',
#  'The shirt is a particular style... ',
#  'The decisive engagement was then put out between the Vemen and Sperton inventories.',
#  'There is a variety of definitions that are used.',
#  'Most of the Markets are white, but there is also a very rare pink mark.',
#  'Almost all these are in hag prices donated that everyone who enters the room will have to pay.',
#  'He slipped in the subsequent decades and his excession is unknown.',
#  'He has the ability to change his head by up to eight different directions.',
#  'There she wrote as "Terrone" on her only "only admiring column.',
#  'How far can we build it up?..',
#  'Who can you say you can we turn to Richard?',
#  '"An old horse," said his lord ship is in heart pain.',
#  'In now she hates to be cowering at these times.',
#  "Steven Collin has developed his music format in a collaboration with Emana's concept.",
#  'It was initially proposed that the frigas would not make the fancis arms.',
#  "Gise, my mind's in the dark gadgets.",
#  "His song is currently played by Ohio's pride, but universitally-audimental marching band.",
#  'The "Artistry of Music" is the organizing body of the folklorama.',
#  'He read English at University College, Cambridge..',
#  'Two yelly asses, each with a sign to the wings and senter.',
#  'Oriente who is the third player as a center half with Airfield.',
#  'Her high-angle directional antennas can also be built.',
#  'They were operated in the City of Melbourne, the capital of Western Australia, during the period.',
#  'The next one opened in Roscommon, New Hampshire, during the same period.',
#  'The route of steel during construction period...',
#  'What a master of the martial arts on the field?',
#  'It was the first time the island had a permanent.',
#  'On the other side, the main street is soon to be named "The Square" in the centre.',
#  'The Java is this variant of the Java Java.',
#  'He studied jazz with Maria Belles...',
#  'The ward itself has also gone through many changes.',
#  'She was named for John Paul Jones...',
#  'It is part of the Horticultural Region..',
#  'The work was carried out by Fred G. W. and a agricultural technician at Golan.',
#  "The port's president is John of the World.",
#  'Breck-Strick has sometimes been referred to as "Gan-Darling".',
#  'In addition, I collected the oral histories..',
#  'The recycled mine was and trusted to be a significant source of future production.',
#  'Hmack Shatter plays as a team captain.',
#  'All the Hose\'s original album is considered to be "Unecolicendable".',
#  'Barkwood Railway is named after Londonderry, a railroad station originating from the area.',
#  '"Wish ideal from which the political parties were afferent," said the alchemist.',
#  'Her mother wrote extensively about the internal problems the family faced at the time.',
#  'An agreement was also reached about improving access to the station.',
#  'It is located for miles north of downtown Pittsburgh, Pennsylvania, at Riverview Park.',
#  'Membership is a right appointment by the superbats.',
#  'Hugh Venet during her ten years as first lady of New York.',
#  'But the danger of war was never far away.',
#  'The big chicken was commonly used as landlocked or driving bikes.',
#  'The owning community of "Hoorm-Mare" is located in the town.',
#  'New Zealand, Canada and the United Kingdom had considered similar options.',
#  'We do not have a budget that is practically not attainable.',
#  'Durings are not plainer, but are very similar in terms of dimings.',
#  'Deriving includes portions of the former cities of Nurna, Tarrant, and Urke.',
#  'If you paste it into a conjunction, the function returns no.',
#  'Oh, is it bad?...“',
#  'Many net networks have to carry on with general traffic consisting of data and data.',
#  'For out the series, his botrail of snipe ganod was widely considered critical.',
#  'The line-up includes a granny, ball-cocking, killing her husband, Alex L. Lloyd.',
#  'He was a perfect opponent in one of the most trusted circles of consuls.',
#  'She specialises in black and white overhorses.',
#  'At the age of six she appeared on "Gandicama".',
#  'According to these orders, the marines continued to serve.',
#  'He was the son of John B. Burns, rector of Colchester and Sharjah.',
#  'He also played for the Big-Mareers in the English Super League at the age of 28.',
#  'Since this time, the company has produced six more compilation books, completing the correctors.',
#  'This type of the pingpong has been shown significant losses in memory of the game.',
#  'His birthplace in Lusitania, Italy, is known as Lusatania.',
#  'The Sega-powered multiplayer game "Fantasy" is played in combat.',
#  'I break down information to the point of its usefulness in military planning.',
#  'A train crossed a disused bridge apparently manned by union members.',
#  'The Pioneer Room has three church of God and Warwick University archivoir materials.',
#  'The main attraction for visitors is feeding tickets from a race observation chart.',
#  'The mast first buned and then snubbed at roughly half is tight.',
#  'The lab can be hundreds of samples...',
#  'In the case, the lag granian exhibits peripheral thermal cycling.',
#  'It is located on Eastern Parkway, on the hillside near Army Plaza.',
#  'She is heard murmuring in physical fear..',
#  'His work was edited by David H. C. Cineck.',
#  'She encouraged solfiosiness, a work of the technical and artistic worlds.',
#  'During the French innovation in Mexico, fast food became popular in the open classes.',
#  'One of his children, who is passing away, is targeted in her attack.',
#  "Oeonia is typically even colic, and is a source of the sick and elderly's symptoms.",
#  'There is a small weekly newspaper in a town called "Heaven on Land".',
#  'There he fought in the wars against the invaders.',
#  'Moderate Democratic parties receive more money...',
#  'It was dramatic... it was dramatic!',
#  "Jack's springing can also be used in some warm-up exercises such as swimming.",
#  'He also is the final configuration in the monster opendament.',
#  'Prescription has also been found to be a valued measure in patient patience.',
#  'A Japanese workfare when leaders fall silent with sad smiles.',
#  'Many contemporary scholars, however, believe Ias a general intelligence.',
#  'When the window was open, the form was pushed open and pointed in the direction.',
#  'Many other songs on the album are collaborations with other artists.',
#  'Then they called the area their "lack of knowledge".',
#  'They make attacks again, again, but this time they will destroy.',
#  'Problems was made slowly, until later insurance counted the pack once more.',
#  'A turtle hatchery is located in Benckick, Canada.',
#  'The reserve also has colonies of endangered cormans and rare pelkins.',
#  'Ironically, the music to the movie "Jaws" exemplifies the minor second.',
#  'There is only one weak day round trip from the Hudson terminus.',
#  'The book is "Shakespeare\'s eighteen throll" and his third collection of short stories.',
#  'The field of patrol is particularly dependent on desert missile technology, known as "Kavula-Kavigua".',
#  'Several composers have put the seven last words to music.',
#  'Several elderly people are relaxing on the beach..',
#  'a room of young children holding a pose..',
#  'The forming is a passion for these dancers..',
#  'The vinhols loders are light and fresh.',
#  'This is the most popular time of the year.',
#  'Another beautiful play is "Slegg" by Yvonne T. Schischrated and Brent Allen.',
#  'State schedules may vary from federal schedules...',
#  'The track was a near bowling of the track.',
#  'Come on Tune was more in the contemporary era of "Hollywood".',
#  'Wena M. N. C. was not involved as a result of this murder.',
#  ...]

# %%
test_df['pred_text'] = outlist

# %%
test_df
# Out:
#                                              input_text  \
# 0                   hanno rot of his expedition in stel
# 1     little enla difer for many other meimhberhoods...
# 2     u as us had the obbelity to fogt on the song t...
# 3     his majors possor is ungariicolmunications a t...
# 4                the mansion also has a marriage office
# ...                                                 ...
# 1995      i wer return ears mashare bebot this mist him
# 1996  one of the man oite arept es an antanpent oftu...
# 1997        we ced stated that he himself with cattolic
# 1998  the judge groled a complaint was not wellid fo...
# 1999                 pe bold the song esabetion of line
#
#                                             target_text  \
# 0               Hannu wrote of his expedition in stone.
# 1     Little India differs from many other neighbour...
# 2     Users had the ability to vote on the songs the...
# 3     His major sponsor is Algario Communications, a...
# 4               The mansion also has a marriage office.
# ...                                                 ...
# 1995  After three years the shareholders dismissed him.
# 1996  One of the main positive effects is an enhance...
# 1997        Weikath stated that he himself is Catholic.
# 1998  The judge ruled the complaint was not valid pe...
# 1999          He called the song a celebration of life.
#
#                                               pred_text
# 0                Hanno wrote of his expedition in Stel.
# 1     Little Eilidh's death for many other families ...
# 2     You have the ability to fog on the song "The H...
# 3     His major priority is ungariocolomications, a ...
# 4             The mansion also has a marriage office...
# ...                                                 ...
# 1995                I'll return home to meet this guy..
# 1996  One of the main attractions is an antelope far...
# 1997  Weck stated that he himself with Christ the Ch...
# 1998  The judge ruled the complaint was not fit for ...
# 1999          Play the song in the background of line..
#
# [2000 rows x 3 columns]

# %%
test_df.to_pickle("distilbart_output.pkl")
