# %%
import logging
import wandb
import pandas as pd
import torch.multiprocessing
torch.multiprocessing.set_sharing_strategy('file_system')

import pandas as pd
from simpletransformers.seq2seq import (
    Seq2SeqModel,
    Seq2SeqArgs,
)

model_args = Seq2SeqArgs()
model_args.num_train_epochs = 5
# model_args.no_save = True
model_args.evaluate_generated_text = True
model_args.evaluate_during_training = True
model_args.evaluate_during_training_verbose = False
model_args.tensorboard_dir = "runs"
model_args.max_length = 50
model_args.train_batch_size=10
model_args.overwrite_output_dir=True
model_args.wandb_project = "cs224u"

model = Seq2SeqModel(encoder_decoder_type="bart", encoder_decoder_name="./outputs/best_model", args=model_args, use_cuda=True)

# %%
test_df = pd.read_pickle("test.pkl")

# %%
model.predict(
        [
            "Hee walks dogks", "Hai my precous boi", "tteko", "e trade often coing sides with other traes", "he kepts extensive nodes on a cosing playurs"
        ]
    )
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Generating outputs', max=1.0, style=ProgressStyle(descrip…
# ['He walks dogs.',
#  'Have you met my precocious baby?',
#  'Do you know what?',
#  'It trades often crossing sides with other tribes.',
#  'He kept extensive notes on his surviving patients.']

# %%
testlist = test_df['input_text'].tolist()
len(testlist)
# Out:
# 2000

# %%
outlist = model.predict(testlist)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Generating outputs', max=250.0, style=ProgressStyle(descr…

# %%
outlist
# Out:
# ['Hanno wrote of his expedition in "Stel".',
#  'Little Italy differs from many other meer neighborhoods in many ways.',
#  'You as well have the ability to flow on the song "Her".',
#  'His major concern is ungambler communications, a technique to base communications in silo development.',
#  'The mansion also has a marriage office.',
#  "Hinny's can land and lounge on its deck.",
#  'All of the series have been collected into trade paper backs.',
#  'Jane and Roger nearly fell overboard.',
#  'We like to seek clear weather.',
#  "The stream near the river is still called Rideau Brook, after the river's course.",
#  "It is located near the school's entrance to Church Lane.",
#  'The show was eventually staged for four knights at Oaken House in Cambridge.',
#  'Abraham also played for the Atlanta Falcons and Arizona Cardinals.',
#  'The parts were computing against each other, so you had to go through bits.',
#  'The burden for these cost overruns is subsequently transferred to the customer.',
#  "Along with the team's efforts in the Bahamas, this album is the group's best-selling album.",
#  'This book was written in Arabic.',
#  'All I was talking about was it.',
#  'And all the talk about having an egg!',
#  "There's always plenty of time.",
#  'They are lace-like rings, to be used for deep-freezing conditions.',
#  'It is also the last stop before crossing the Williamsport Bridge.',
#  'Pascoe served in the first and second terms of the American Confederate government.',
#  'The caribou and petroglyphs no longer exist.',
#  'Relaxed thin please little man.',
#  "Abbott's risk assessment is one of several techniques currently employed in science and engineering.",
#  'There are other forces changing the rates of change.',
#  'After a time, it became the corporate home of the Hagerstown Sugar Works company.',
#  'Albemore is the county seat of Mendi County.',
#  "As the late twenties wore on, Johnson's popularity faltered with the advent of punk.",
#  'The Megadrive version was released exclusively in North America.',
#  'The title track lyric says "Somewhere later than alive or dead".',
#  'They however, can be stored with a bit of extension.',
#  'The bottom of the shoe had a gold band.',
#  'It now commits crimes which center around penises.',
#  '"You Boogie" was released as a physical single but also failed to find success.',
#  'He recognized the courage of the young man and the high date of the rich.',
#  'He is buried in the Memorial and Cross Pine Cemetery Rockingham County, Virginia.',
#  'Martin is an Englishman in New York.',
#  'Non-re-zero excitation occurs when the incoming radiation promotes a core electron to the continuum.',
#  'The Bougainville restaurants serves traditional French food using modern techniques.',
#  'The district sold the building to the province.',
#  'The original concrete station building has been demolished.',
#  'The President was surprised.',
#  'He appeared on a number of recordings both as a sideman and as a keyboardist.',
#  'They need to keep junk out of the market.',
#  'Comprising city and county government and private sector representatives, the constituency is truly gains.',
#  'The turquoise drop was stored in a vault.',
#  "He promoted the station's presence and comments both in the United States and Australia.",
#  'For example, a spoon may be used for both spade and spade applications.',
#  'He played in the National Hockey League with the Toronto Maple Leafs.',
#  'Our promise is Missouri State University is our newest capital campus.',
#  'Birds emerging from fays in destress and from drowning are also commonplace.',
#  'Junior Rugby and Football players were sipping drinks.',
#  "That's the main idea.",
#  'With a back of march mellows.',
#  'She made it clear that she is married and not in the business.',
#  'The reaction is called the "Hudson\'s Syndrome", after Henry Hudson\'s "Eagle-Eye Reaction".',
#  'He represented Quetta in the Irish Civil War scene at First Class Reunion.',
#  'Before going into acting, he trained at the Pasadena Playhouse, where he was a dramaturg.',
#  'The firm is the sponsor of several corporate securities, the publishing industry and a charity.',
#  'In later years, Hensley stopped leaving the programme, which continued with other pre-programmed themes.',
#  'And the spacecraft design and weaponry have made major changes through out the years.',
#  'Then Admiral Adamas read the text, calling it the "Old Testament".',
#  "Mazak's North American headquarters are in Anaheim.",
#  'This two games are at home and the other three at Wandsworth Park was separate game for each team.',
#  'It was a small part of the Chistochina and the Anaran district.',
#  'The area was named after the town of Kilkenny in Ireland.',
#  'He also studied painting with Franz Raphael.',
#  'The broker sells instant chocolate bars next to conventional locks for an expensive fee.',
#  'The amateur compilations learn from real world dog fights with real dogs.',
#  'It is the first game in the new season.',
#  'Unfortunately, all the noise is frying the system.',
#  'Nephi High School is one of the schools in the district.',
#  'In the same article, Guarneri denied that he condoned prostitution.',
#  'During her literary career, she has written pottery, fairy tales and essays.',
#  'Dorothy was born in Arizona, United States.',
#  'The older of the two brothers, the younger is known as the "Parrot" or "Sleeping Seal".',
#  'It was free to view in this window, being of tribal decent.',
#  'The film received its second Best Screenplay nomination in the British Academy.',
#  'It attracts a lot of fishermen, camping and fishing mahalaya fish.',
#  'He was born on a farm near Bugwash, Nova Scotia.',
#  'So where are the language boarders?',
#  'It is popularly known as "Miracle Serenade".',
#  'Starfighters are equipped with different weaponry which can be highly effective in certain missions.',
#  'The agreeableness test reflects individual differences in general concern for social harmony.',
#  'On the lower back there are three craterlets, capped with red briers.',
#  'Eventually enough were disuaded from this action.',
#  'And the inhabitants are known as lads and gentlemen.',
#  'The old and wise could get a new and wise master.',
#  "What's the matter?",
#  'He made a small killing.',
#  'She has her slightly bug-eyed look.',
#  'However, when it comes to neuroneurone, that is something one had no conscious control over.',
#  'However, this method offers significantly less security than the one for automatic transfer.',
#  'This kind of convection is referred to as a pneumatic current, simply "spots".',
#  "It's normal to freeze before events.",
#  'In most cases, it forms more or less a line of sight, or a row of seats.',
#  'There are many famous African and African descended people in the city.',
#  'There are two main churches on Carrow of England and one Methodist church.',
#  'She was born in Saint Denis, Luxembourg to Morag and Bernhard Bernd.',
#  'It is the design that creates the ideal space for office space and office walls.',
#  'This is why I think this file is filled with all the nastiest of corruption, fraud, and counterfeit.',
#  'The current and historical significance of the station is unknown.',
#  'Members of parliament were not compensated Duke by public subscription.',
#  "Burials were found in the slaying body of Kluge, Marquette's second wife.",
#  'The obituaries mention a place by the name "Tabtaba" at the northeast corner of Africa.',
#  'This was after meeting with Sycho-Alchemist and Goethe.',
#  'The lease term expired.',
#  'Is this some sort of test?',
#  'The brass notes were struck perfectly but surtitles were played by the alto.',
#  'A bridge is the foundation of any successful building.',
#  'He was the fourth best scorer of his class.',
#  'The settler had in turn hired a gardener and two housekeepers.',
#  "In this morning's rain, there was a swell of the will.",
#  'The celebrations and the party were very successful.',
#  "While it is a well-trodden way, the shire's boundaries form a barrier to the second kingdom.",
#  'Its slopes are wide with fine fernspots.',
#  'He was to star in "Thelma".',
#  'This leaves the house on the side which is now a nature reserve.',
#  'On November the astrological position was from a rookery island.',
#  'His family has operated a farm in Leflore County for three generations.',
#  'He concludes that with his death, the galaxy has become a more dangerous place.',
#  'This is an alternate form of regulation for the "G" system.',
#  'It was an old cart.',
#  'A one stone does not make a pound.',
#  "He was the son of Professor and Ella Sirsan's daughter.",
#  'These rivers are the hubs of the Hypaporibus and the Cocheta.',
#  'He was an unpopular king and favored his younger son.',
#  'Take care of the chickens, and the pears will take care of themselves.',
#  'They are used in manufacturing of active paste for the dyeation process.',
#  'There are also several bus boarding stands available at the airport.',
#  'The school is located by the river in Naco.',
#  'And then things happened very quickly.',
#  'During the while, one of his students had been to his house and seen his artwork and the surroundings.',
#  'The magazine\'s "Press Prize" is awarded for "Six-month Best"',
#  'The museum sponsors the towns of Cruisers, Cruisers Show, Jukebox Nautica and Renigamia.',
#  'Normally, the lonesome would not attempt to dispose of the objects fairly.',
#  'What were you talking dirty about?',
#  'I generally sit indoors and listen to the wireless.',
#  'How did you produce this?',
#  'The series has half-long stories told by bodies of the seven main characters.',
#  'That aroused suspicions the next day after Lincon was assassinated.',
#  'The Security Council lists member states and their central banks that mint their own currencies.',
#  'The Metrorail elevated tram line runs through the park along its westbound route.',
#  'The union is known for its opposition to a definition of marriage and same-sex marriage.',
#  'This text addresses the philosophical mology of the game universe.',
#  'Gambier was that ax-throwing star that robbed the Raiders of an opportunity to win the series.',
#  'It is a well-known line of business that saves the mine reserves.',
#  "We're all home, I am sure.",
#  'Broy was also subsequently used as a military officer in the Afghan Empire.',
#  'Her sisters are a charming bunch.',
#  'He also co-wrote the book "On the Borderlands" with Margaret Verner, originally titled "Batsman".',
#  'The company offers free landscaping programs that receive royalties from their creations.',
#  'Similar to a yeast cell division, the formation of the isosynoid is a polypeptide.',
#  'He was decorated with the Order of the Deutscher Kreuzkugeln in Oswego.',
#  'The village is called Maya, after the river god.',
#  'The capital city is also called Cabanatua.',
#  'And this one time, the sun rose.',
#  'The team is relegated and can disband after two seasons.',
#  'It is the home of the Ortenzian Jewish Publication Society.',
#  'Macau is a member of the Conselli branch of the socialist party.',
#  'He lived in Raleigh, North Carolina, United States.',
#  'Digital manipulation relies on no single technique but instead utilizes possession from multiple inputs.',
#  'Adverse drivers and cyclists are effectively prohibited from using the tunnel.',
#  'The party has a Arab-American Advisory Board.',
#  'He was defeated by Durban in the November election.',
#  'When compared to those of interior Alabama, Mississippi and Tennessee.',
#  'This is now the site of the Humberside offices in Sydney.',
#  'Several notable naval engagements occurred off the Azores station.',
#  'The railway names Millburn after a different fossil species.',
#  'He would often read the bible while shaving.',
#  'Out of this report came the Ark of the Moors story.',
#  'Some speak the Highland language of books and articles.',
#  'What is the best form to medicate?',
#  'He looked like one who had passed through an uncomfortable hoof or two.',
#  'He had no idea what was in that little revelation.',
#  'The old village is still distinctly visible surrounding the old White Village church.',
#  'He was educated at Harrow School and Trinity College, Cambridge.',
#  'This site came to be used for the river as well.',
#  'Settlements are generally said in monterrey terms or zonally.',
#  'Briand and his deputies.',
#  'They were replaced by the single standard instill shield system in March.',
#  "A long, big screened credit card screen means you don't see the slag.",
#  'He was born of history, geniuses engineers and brilliant mathematicians.',
#  'Abbotsford station has a single platform, barred from serving by through traffic.',
#  'The old village was abandoned and all of its buildings are now dangerous.',
#  'Like India, Bangladesh has a distinct culture.',
#  'Its name comes from the Greek word for "flower".',
#  'It was his last chance.',
#  'These programs usually follow a linear storyline, although occasionally they feature segments and alternate endings.',
#  'The billimeter will allow your mewing mouse to make contact with the lubricant surface.',
#  'In classical French, parish to parish marriages cannot occur in succession.',
#  'He tended to dig in clay and memento.',
#  'Of course, all children under five years are expected to be free.',
#  'Royce sings live jazz, and she dances as often as playing the tarp.',
#  'In its very season, "Mizrock" was critically well-liked.',
#  'The record fell in the following year, almost eleven months later.',
#  'The journal constitution declined to publish "Mines" again.',
#  'This becomes prohibitive with realistically large blocks of iron.',
#  'The third chair is awarded two-year term.',
#  "Some of the lower level in the women's section remains a humour of strikement area.",
#  'It does not function as a separate division within the same division of the division.',
#  'Blackwood later became a partner in the business with Shar.',
#  'Maktuba was subjected to the harsh punishment of the Nuremberg Laws.',
#  'Does the ant have equal rights?',
#  '"Calisthenes," said Mr. winkles, "reached us from the other side.',
#  'The experiment also eliminated some nuclear warheads in the process.',
#  'She and I were such a close relation.',
#  'These rare levels strik a better balance between puzzles and action.',
#  'His legs could be called serviceable.',
#  'He was the eldest son of Major David Smith and his wife, Harriet.',
#  'The tour was being planned but was eventually scrapped due to financial concerns.',
#  'This film is the ultimate proof of the concept of the desert.',
#  'I got outta there and broke it up.',
#  'After graduate school and one year at Princeton, Elba is a social worker.',
#  "Bacon was succeeded by Carey O'Sullivan and Mike Kemp.",
#  'Malham should not be mistaken for Malham Air, a business aviation company.',
#  'In doing so, he destroyed the bus.',
#  'Currently, has he is employed as a one-man-show at the Centre.',
#  'The mobility of the compass is a problem on the Babylonian plane, with rare exceptions.',
#  'Burrell County, North Carolina is named for him.',
#  'Glacier Manning also played this role in the film.',
#  'Tramayana was competing in a hard-hitting three-part feature film series, "Running for Mins".',
#  '"I\'m not sure I\'d be able to do that for you," the alchemist answered, without turning around.',
#  'She was the flag bearer for the Winnipeg Jets during the Winnipeg playoff series.',
#  'His album has been renamed as Best of the New Millennium.',
#  'Being able to do both on the same subject matters keeps me going in each session.',
#  'Every school has its own cultural and religious values to adhere to.',
#  "The band and some of the band's promotions were non-singing.",
#  'The building was built in one day on a pine forest.',
#  "Don't you play no?",
#  "At one time, he was the team captain and was the club's vice-president.",
#  'A church will be built in his honor.',
#  'The one hundred largest towns in the district.',
#  'Dewall faced Republican Nominee Handsworth Lewis in the Junior collection.',
#  'She is a national medalist in True Blue for the event\'s "Waterbirths" series.',
#  'The game requires the player use both mods of play.',
#  'Under the scorch both in a freshment stall with sword and other things on display.',
#  'When the tides are at an arid season, the islands will begin to appear on the same day.',
#  'He looked around the islands, whether wizarding or not, and the moon was disappearing.',
#  'The mind is now closed; it is now primarily a center for animal culture.',
#  'Unless otherwise noted, the main source of Nielsen ratings in the newspaper is the "Boston Post".',
#  'He also expressed his support for a moderate social reform.',
#  'Shanks attended the University of Texas at Austin, from where he received his law degree.',
#  'A variety of activities take place in Paskaskany Hills.',
#  'He was a longtime associate and co-chair of the program with the programme director.',
#  'The castle walls still exist today and are now a tourist destination.',
#  'The current Director is from Cornelia University.',
#  'House is a typical three bedroom family home.',
#  'The state plaid is used on governmental buildings and embassies.',
#  'Then they spat on her and hated her.',
#  'Besides, this was the first time I had heard of the sun setting on thirtieth.',
#  'Faro was the son of Cornan and Cornan Canona.',
#  'The album includes the compilation track "Running Wild Again".',
#  'The stairs also can be increased with base stairs.',
#  'Wait till that little guy gets here!',
#  'In these works, Glass used repetitive structures, often articulated with musical minimalism.',
#  'He was a member of the moderate Republican Main Street Partnership.',
#  'Their size and shape are regular because they are not perfect spheres.',
#  'Today, the Veltronic crane is again manufactured in France.',
#  "You're a great writer, I tell you.",
#  'The current holders are All-City Rugby in Henry Bolton.',
#  'The album was highly acclaimed by critics.',
#  'The official opposition was the liberal party led by Alexandra Makarkin.',
#  'An excerpt of the track is included below, played during the first video release.',
#  'But he would be divorced eight years later.',
#  'Wondrous things crook in tock of food.',
#  'There are numerous international hotels in the district.',
#  'The school was funded in the Finnish monasteries by Roman Abramovich.',
#  'The models for the new campus included the Technical Institute, colleges and schools.',
#  'The concern is that these databases usually present one version of data entry error.',
#  'These computer programs are sometimes forced on devices like computer systems and mobile apps in schools.',
#  'He attended the wedding ceremony.',
#  'The program imitates normal Shabat brogrammy camp.',
#  "The team's mascots are a yellow tea capper and her sister, a blue tiffin-kerr.",
#  'It may be the site of a recent eruption from the vicinity.',
#  'The exterior scenes were shot in Burbank in Burrows, Wales, Australia.',
#  'Native American settlers quickly replaced the native population.',
#  'The most significant of the early designs was the "Heroine" character.',
#  'For example, one could rely on certificate authorities or a written warrant.',
#  'That night, as at the Pyramids, the sun rose about six thousand miles away.',
#  'Three people in a kayak float in the water at sunrise.',
#  'Two guys are sitting in a field with plans behind them, playing cards and plans as they move along.',
#  'A bicycle riding down a road with red and black checkered markings.',
#  'A little boy on a red bike.',
#  'This model is furthered developed in higher levels of undergraduate studies.',
#  'The Monday Night Football lived up to its billing.',
#  "Al-Assad remains one of Egypt's most underdeveloped states.",
#  'Copalooba has a tropical and desert climate.',
#  'You guys can do this even faster.',
#  'The routes are unclassified, while the routes are included in the overall structural scheme.',
#  'During the engagement, the relationship supersedes the other two relationships.',
#  'It is also available for evening concerts.',
#  'God save the Queen!',
#  'They told me, and called me back.',
#  'It is long and steep, and steep at a higher gradient.',
#  'She played the violin and sang a few songs at the concert.',
#  'The narrow and poorly-lighted Ponda Strait, northeast of Mangalore, was especially affected.',
#  '"Because I\'ll give you a good scream, play, or sincere apology," said the monk.',
#  'A culture is similar to furtivity, the natural capability to produce abundance.',
#  'Crancon used statistics to make financial trading decisions.',
#  'The site of the pub is local.',
#  'His memorial cross was displayed at the National Museum of Military History in Jena, Germany.',
#  'The Carson family lived in modest conditions; father was a miller and clockmaker.',
#  'Also, there is a pub opening at the station main entrance.',
#  'Kozak also urged the country to become a "spring of an enlightened nation".',
#  'Many of these paints feature Himalayas, hence the name of the company.',
#  'She served as an editor of many academic and professional journals.',
#  'Frederick and Clifford Robert.',
#  'One of its most important commercially growing species is oak.',
#  'It is also known as a perferer and occasionally as a fizzer.',
#  'Confessions are required, but only the "seer" can be head of such a group.',
#  'The general counsel of the party, Josef Schumann, resigned.',
#  'In time, it has become a favorite to many gamers.',
#  'Mak and walked together up the hill to the hotel.',
#  'He leaned forward and shook his head with a smile.',
#  'He is a very smart man, very smart indeed.',
#  'Settlement in Koplik was assisted with the discovery of a gold ore deposit.',
#  'He introduced a bill that directly challenged the discriminatory laws imposed by the local authorities.',
#  'Minear began his career on structuring relationships with friends from Cambridge.',
#  'They can be found throughout Europe, particularly amongst the fraternities.',
#  'Some in the mediatheat are riding a motorcycle.',
#  'Several roads, town courts and synagogues had to be relocated.',
#  'Thomas Crumwell was the first editor of "Maxine".',
#  'Recently it has undertaken extensive renovation and refurbishment with clubs throughout Europe and Middle East business.',
#  "The child was immediately given to Lovelace's family.",
#  'The city of Terren, where the construction took place, has far fewer inhabitants.',
#  'Also, Reinhold describes "Frazier" as a "masterwork" that evokes a black and white image.',
#  "He pointed out the flaw in his brother's argument.",
#  'Is that program proprietary software or is it open source?',
#  'A former mayor is giving a speech on Friday.',
#  'Only so-called "Metrix" or "Bivariate Beta" can be a continuously stable stat in single-period time.',
#  'The Iron Guard was forced out of the government.',
#  "The third vacancy was created after Alderman Robert Santangelo's death.",
#  'The grips can be the wood or a mirror image of handle handles.',
#  'In this series, Hawgan causes problems for the locals.',
#  'There is one three car parking area for this station.',
#  "Why don't you play and let's make them?",
#  'Here, he met with success, establishing a medical practice that prospered quickly.',
#  'The two bricks have fallen by course.',
#  'All of the British settlements in Cape Breton were completely abandoned.',
#  'The university is named after an umbrella term for biological researchers.',
#  'Kettlebells play a similar role, but the plastron is graded and modified with age.',
#  'The development is due to be completed within seven years.',
#  'It lies within the City of Charles Town.',
#  "England and Wales are where Cooke's parents and stepfather grew up and met.",
#  'It was created by trauma researcher Peter A. Evans.',
#  'Not one notice her.',
#  'We will not take up another early draft of a story.',
#  'Increment the order one byte if you require more than one item.',
#  'Along with Carpath, Bechem brought sixteen new members to the kingdom.',
#  'The most popular programme was the morning show with Adrian Blades and Susannah Morison.',
#  'He could not have stoned the animal.',
#  'He left his family so he could systematically destroy and construct the resources they needed.',
#  'This was called "Cassell\'s" at the time.',
#  'Rosen is located at the northwestern end of the Dark Age of the desert.',
#  "The album cover features Snoopy and has fans including Snoopy's girlfriend, Betty Page.",
#  'Mistress Karen lives on the land of the maids.',
#  'These fields were used for a near-by commercial trade of cotton, wheat and apples.',
#  "Lofting was educated at Mount St Mary's College, Inverness-by-Shire.",
#  'There is a large gap or deformation separating the cheek teeth from the insisors.',
#  'Canada requires tax deduction at source and payments of compensation by employees.',
#  'But even finding the center of gravity of this sphere accurately was difficult.',
#  'The river runs slightly west of Choctaw.',
#  'Herring, a Holly sword, or one or other martial symbol.',
#  'Wandin and Nike are locking lips at home, play at a football stadium.',
#  'The former main man and grammarian, Joseph P. Quinby, filled the vacated position.',
#  'Since then she has also acquired a substantial stake in Fairfax Media.',
#  'But this said, there is no indivisible dimension from interior to outer.',
#  'Kosha is located in the Verdi School District and has one elementary school.',
#  'They were subject to systolic injections as part of their medical treatment.',
#  'Down the road is another regional administration that also merged with just south of Connecticut.',
#  'Are there any Roman names in Ecuador?',
#  'When a person is in two worlds, it is described as "living in two".',
#  'Rain is very frequent in this part, and weather often changes quickly.',
#  'Nothing is known of this period and his life.',
#  'It is fed to the sudden combination of light and vision.',
#  "Johnston's supporters support him without an explicit declaration.",
#  'Margaret courried with her teacher to get better grades.',
#  'The alarm panel should have both a buzzer and indicator light.',
#  'The Australian bicolour darks are the biggest of all types of darks.',
#  'A side from his father is "Eye of the Storm", a cricket commentary by playwright Kenneth Robson.',
#  'They have two children: North America, North America; Australia, Australia, and Japan.',
#  'The national park is located west of Esperance on the southern coast.',
#  'The court of appeals denied this reasoning and upheld the conviction.',
#  'Saint Thomas also has many factories for food processing and electrical equipment.',
#  'The title also appears as a line in one year of Lovelace.',
#  'In his youth, Mike Dat was a googler.',
#  'In all other instances, such collaborations were often short-lived.',
#  'It has been described as "the third-largest building in Washington".',
#  'An entrepreneur is a valuable example of business success.',
#  'Playing the instrument, the music may be played live or recorded.',
#  'Shakespeare plays the long poem "The Humble Servant".',
#  'The winning theme of the program was Ace Challenge.',
#  'The school operates under the supervision of the Junior Achievement School Board.',
#  'He confessed and went to prison.',
#  'Conroy undertook a tour of Germany, Austria and Hungary before starting at Oxford University.',
#  'They are not currently performing.',
#  'He never returned to school.',
#  'The water flows through most of the channels of the river, until it reaches Smith Reservoir.',
#  'The rooms are designed to accommodate four women each.',
#  'These drugs may have systemic side effects including diabetes and peripheral symptoms.',
#  'Four pedestrians and the ferry remain free of charge.',
#  'Cannabeed is also extensively cultivated throughout the city.',
#  'Others do not behave as clearly like monocleic dipsticks.',
#  'The island is northwest of the Settle Beach State Reservation.',
#  'He studied naval medicine at Tufts University.',
#  'Initially she worked with Inga, arranging his escape from the Pyramids.',
#  'It was named "Sylvanus" after the Egyptian god of the desert.',
#  'It is not a life sentence, it is a tenet of the law.',
#  'Sticks and stones being a common tool for gatekeepers of land.',
#  'This movie was featured in the film "Inconceivable".',
#  'They do not create and experience that in real life.',
#  'Generalizations developed for the variable adnio are used for standard algebras.',
#  'In some situations, such as live seeding, the plankton of the vector is wetted.',
#  'He is married with two children and is the father of a fourth child.',
#  'There is also a pub crawl in the neighbourhood, called the "Tornado Run".',
#  'You can replicate this process in different ways to obtain the desired result.',
#  'She went to bed destressed, and woke two for heads.',
#  'There were no fashions or ties.',
#  'But all his work is available for purchase on Behrs.',
#  'He was the older brother of American novelist Curll Bennett.',
#  'Buddhist chanting the House Code for Koxinga is some dark medieval Moorish magic touch.',
#  "Tom arrives at Connie's house to find her hand cut to the small of her back.",
#  'Shortly thereafter, Stuart began work on his Mount Washington hotel.',
#  'It may also be associated with nervous-system anxiety, depression and other psychological disorders.',
#  'The cap is five inches in diameter and five inches high.',
#  'One form of the reference line is the use of the tridye-linked serialization method.',
#  'The airport has two public platforms, one for international and one for domestic traffic.',
#  'She played in the late-Elizabeth Florence Creighton series of films and television.',
#  'Sumly, the school that she attended respected a very different way of doing things from her families.',
#  'Watford was extremely difficult to return.',
#  'It is a carnivorous ratfish, fish, and insectivorous fern.',
#  'Out of the mouths of baboons, one falls to the bottom after a while.',
#  'It is affiliated with the Realist School of Farm Policy at Harvard.',
#  'The first was somewhere in England, where it lived its grand life.',
#  'Once both were dead, however, their successors became embroiled in war.',
#  'Return of patronage following triennial votes varies widely among individuals.',
#  'He last played professionally for Notch County.',
#  'At that time, the two schools existed separately, with two separate commanding officers.',
#  "For better or worse, it's a good thing for us.",
#  'The album was released with the bonus track "New Zealand" as a single.',
#  'Morris provides the five distinct wood bins.',
#  'The people in the plaza are of African descent.',
#  'However, the school no longer holds this ranking.',
#  "Cyborg's wife, Tessa, signed a three-year contract with the firm.",
#  'These are documents of intellectuals and resistance against National Socialism.',
#  "Prior to his mayoral assignment, Morey served as Cambodia's president-in-waiting during the Khomeini's governorship.",
#  'We need to run the meter again at eight.',
#  'Farnham County Council serves the city.',
#  'Located in the same area are more businesses.',
#  'His most well-known were the open-air dances, which would drop pieces from masts around.',
#  'There are two main initiatives to establish a Green Space in the area.',
#  'The North Staffordshire School District is headquartered there.',
#  'And I have a liking for rust and fudge and cor flaps.',
#  'Where do foxes live?',
#  'Do you know the exact district where she fell?',
#  'In an attempt to explore, he does not listen to reason.',
#  'The pills are ready immediately for administration and clenching.',
#  'The president has the right to specify the legal and administrative consuls.',
#  'If good men had learned the roles down the film would not have been made.',
#  'The family moved and spread across Canada, Newfoundland, Newfoundland and Labrador.',
#  'Some infinitesimals will also not play any capture inside moving objects.',
#  'Teaching, laboratory and laboratory experience.',
#  'The infront of the cathedral is a large ornate doorway, almost circular.',
#  'Man will not be subject to any external influence unless he is drafted into the Army by a commander.',
#  'The area has a small community consisting of mostly of elderly people.',
#  'A liquid formulation is effective for the treatment of respiratory symptoms in asthma.',
#  'The show was named for Federic Cambrai, a Welsh traveller, poet and actor.',
#  'Other renovations include a new ceiling, new lighting and a new floor board.',
#  'They have also been recorded in other countries, including Australia and New Zealand.',
#  'These body-water interactions altered water circulation patterns.',
#  'Two and a half decades later, the term was introduced.',
#  'Little England is known for its twigs.',
#  'He is joined in her quest by Frisbee, Bowie, and Sober.',
#  'As a result, Armstrong replaced Gifford as head coach of the Cornishmen.',
#  '"We shall be fine," he said.',
#  "She's up to tell tales about it.",
#  "I'm really a wild beast, you know.",
#  'She was the only woman with him, your young friend thought.',
#  "That's what Karen got.",
#  "I'd give a thousand if a few producers would give me fifty.",
#  'The fighting had now become intractable.',
#  "except for your father's blessing, and with it this.",
#  'The album quickly spread throughout the punk community, earning the band national recognition.',
#  'Fowler was born and raised in Kennett Square.',
#  'They just had no idea about that.',
#  'He was elected president of the New Zealand First party when Doug Wotton resigned.',
#  'It has two serving platforms and uses a ticketing system.',
#  'The truly remarkable feature of the book, however, lies within its diatronic, surreal drawings.',
#  'He has two daughters, Mandy and Jessica.',
#  'The gardens are open to the public every day of the year, except Christmas.',
#  'It was Mink that had negotiated the technical exchange agreement, an extra capital with Westinghouse.',
#  "His father, Charles V. Coffin, was first cousin of Erich Hoffman's father.",
#  'Prior to this, the "Herakask" consisted of radio "Canada\'s Radio News", with locally inserted images.',
#  'Vickett played college football at the University of Southern California.',
#  'He was chairman of the West Virginia Republican Conference for eight years.',
#  'General consensus is that the proposed measure is not sustainable for the long term.',
#  'A collection of items from his cape collection.',
#  'He was the son of the colonel of the Cochrane County Cavalry, where he still studis today.',
#  'The soundtrack often featured trance music.',
#  'The village of Floss springs is served by the Union County School District.',
#  'It flows north and west to receive the Stoddard River at the town of Roscommon.',
#  'He wrote many novels and short stories.',
#  'He activated the stopwatch on the sixth oasis.',
#  'Collins named her because she recognized him.',
#  'Wolff also participated in the opening of several postbellum branches in Australia and Austria.',
#  'It was therefore divided between local authorities from a fairly early time.',
#  'Soon we were on our way flying to Oz.',
#  'The school has continued to twin with the Woodgate School in Nuneaton.',
#  'The city is named for the ideal of political unity.',
#  'Oh, my sisters!',
#  'Evaluation is placed on those discoveries affecting human life.',
#  'Later, Jack Miller wrote "Revenge of the Melvilles", a humorous satire.',
#  "A good portion of this was lost during the Utah War and Utah's descent.",
#  'It was based on a hatchet housed in a tool pouch.',
#  'There has been some confusion over when the quote back to the original quote was released.',
#  'Public institutions in Dacia are placed under provincial government.',
#  'Over the years, he has pursued a simple route to travel and plant-hopping.',
#  'Four years later, she took him to dress in.',
#  'As a squadron, the squadron is equipped with anti-armor, anti-tank, and anti-radar fire weapons and armour.',
#  'He attended Dudley Middle School.',
#  'The explosion raises a large amount of moisture laden air from lower altitudes.',
#  'It is originally named the School of Commerce and Domestic Science.',
#  'He was driving with his daughter, Anne, who survived the crash.',
#  'Once he sensed that you were prepared, he was thoroughly professional.',
#  'The company also has a wholly owned division called "Nestle Servicing" and now games.',
#  'Hangar has little to no rest facilities on site.',
#  'The Parish consists of four hamlets: Upper Wood, Upper Wood and Lower Wood.',
#  "Robert Vasion and Maxwell O'Sullivan look on as axes protrude from the entry.",
#  'The red brick oven is preserved in the surrounding Marion County Courthouse.',
#  'The extent of compulsory education in military schools is debatable.',
#  'Hope they release the political prisoners or it will be a sore death for all of you.',
#  'It is bordered on both sides by the city of Myhata, Toggenburg.',
#  'The issue with this conclusion is determining the correctness of the interlinked operations.',
#  'Furthermore, there was considerable difference in the authority files of the different libraries.',
#  'He kidnaps her, holds her captive, revokes her and cuts out her tongue.',
#  'Following its opening, "Portfolio"s "Stacks" system was gradually replaced by a "Writing slate".',
#  'extremely high energy particles are the result of super-fine crystalline particles and molecular interactions.',
#  'The combination of both animal pictures and one figure has developed.',
#  "Training home and tailor's skills.",
#  'It also offers scholarships and awards to its members.',
#  'From bicycle parts, she listed off bicycle part manufacturing companies.',
#  'It is one of the earliest examples of near lifes sauna.',
#  'Each level starts out with a case to rule and some possible characters.',
#  'The horse and rider was the primary vehicle allowing the men to maneuver for the kill.',
#  'Some of the challenges include jumping rope high and collecting items from others.',
#  "I was just a little kid, so I didn't know how to behave.",
#  'The new version has eleven new features.',
#  '"Go bowling," the seagull said, full of joy.',
#  'I was complete surprise, however, there was no response.',
#  'Say what he has got to say.',
#  'The unincorporated community of Smithers Landing is located in the town.',
#  'All songs written by Zappa unless otherwise noted.',
#  'The following books, "Maguire" and "Honorary Honours", also appear in the British Library catalogue.',
#  "The mayor's term of office was also increased from one year to two.",
#  'There is reception everywhere.',
#  'And how did the directions were look?',
#  'Soon many of you will be walking along Broadway.',
#  'Sugar is in the middle of a manufacturing revolution.',
#  'He was looking somewhere in the sky and tugged at the right lock.',
#  'Saint-Constant is home to the Canadian Repertory Museum.',
#  'The street begins in the north as Albion Road and runs north at Walker Road.',
#  'They were reported to be one of the most rebellious tribes at the time.',
#  'Spence attended colleges next door to the east.',
#  "All the township's south shoreline or north-central portion is in Stoddard Township.",
#  'This batch typically contains oats, wheat, oats, and sometimes rye.',
#  'During his time, he faced several financial problems caused by the Great Recession.',
#  'Computer asks are generally a manual use and requires some scripting skills.',
#  'The car is now considered a collectors item.',
#  'Faris\'s "Silsene Rouge" contains gases of various crystalline species, including argentiferous argentite and argentizine.',
#  'Many women do not actually sit in the log for shade.',
#  'It will come back.',
#  'The letter is usually referred to as "p" for "standard".',
#  'He also developed the "Portraits of America" which are used throughout the country.',
#  'The device codified in this code was the first tethered system.',
#  "The sand store is open on Saturdays, eight o'clock by men.",
#  'Towns could use the term "Sis the Queen" to further praise Bovair as a beautiful princess.',
#  'He travelled through Hong Kong, Singapore and India, working as he went.',
#  'The entire orchestra repertoire is also something that has been formed and recorded.',
#  'I rode the subway because I love my people.',
#  'Following that season, Aguilar went to age out of juniors.',
#  'This generation of players represented Australia at the National Team since their first day.',
#  'His flat was a novelty in this day of math.',
#  'The principal seat of the Lords of Tournai was at Tournay.',
#  'To this end, their wall known as "Chaplin\'s Tower" has twelve storey bells.',
#  'Farms do not have factories in Eastern Germany.',
#  'It refers to a line concatenating of four overlapping lines.',
#  "There is no need to re-invent the wheel if it isn't a problem.",
#  'The new era requires considerable development.',
#  'An unlimited number of on-sale vehicles is available in Netherlands.',
#  "It's now the world's arriving biggest floozels of limes.",
#  'The management of the event was consistent with previous requisitions in the region.',
#  'She claimed the journalist did not know what to be talking about.',
#  'The model Filipino alphabet was written and published later.',
#  'From men on the prowl, it was called "Tobodon".',
#  'Gimney does not appear as a barrier in the motion picture.',
#  'The band enjoyed much regional and some national success and released three albums.',
#  'The foundation supports education, medical screenings, diagnostic testing and social therapy programs.',
#  'The lyrics make reference to murder and corruption, misadventure, gangster themes, and supernatural sfandoms.',
#  'A cloud with a single charge appears from the west and destroys the caravan.',
#  "The city's forests also occur in the surrounding Saurashtra district.",
#  "The mountain's main base of operations was Morana Army artillery and airborne parades.",
#  "Jefferson's original rough draft is on exhibit in the Library of Congress.",
#  'The county seat is Stanton.',
#  'The name of the river is a misnomer.',
#  'This polarization arises despite the presence of an univariate Gaussian distribution.',
#  'It does not restrict certain types of co-operation, but does prohibit certain types from certain regulations.',
#  'Who is Gemma\'s secret homie? It is called the "Silver Dragon" after Gemma.',
#  'Bels are well known for their exploitation of megamanoid species in the area.',
#  'Harrison was the manager of the "News Chronicle"\'s "Weekend Washington Bureau" in Washington, D.C.',
#  'It is a separate entity.',
#  'Bieticarian and leftist politicians were particularly active in the federation process.',
#  'This includes three battalion levels of the patchy attack helicopter fleet.',
#  'They face South Africa on Saturday in their matches.',
#  'He is considered to be the founder of modern orthopedia in Poland.',
#  'Language groups, including monasteries, monasterials, and languages, are highly inclusive.',
#  'Mayday for no reason is a wary old man, there are many dangers.',
#  'Meanwhile, the President would be elected by a majority of the delegates.',
#  'He was silent for the best part of a minute.',
#  'Shared activities included volunteering in local non-profit organizations and free social issues.',
#  'Victoria reportedly was forced to "kigurra" now and most series in retaliation.',
#  'This section is told of a number of new crises.',
#  'After Burns, the band\'s career was gravely affected with the publication of the "Alchemist\'s Tale" and "Theology".',
#  'He would return as soon as he had come.',
#  'Grixon had seated himself under the lamp, and was now bringing it out.',
#  'It is currently used mostly for upper management.',
#  'The album, along with its soundtrack, was inspired by Tarifa\'s "Wulffries".',
#  'The late Latin philosophers will engender the sensation of being more.',
#  'The few published isotopes are usually lower and in some cases lower in alpha.',
#  "Thank you, you've been very generous and kind.",
#  "I can't seem to side right.",
#  'Please help me search the bank and television shop.',
#  'For sambo, I got there.',
#  'This lagoon is farmed by the great field of oats and the related name.',
#  'At the conjugate point, a superposition of both focus states occurs.',
#  'Are you authorized to think of it?',
#  '"I just decided to not write normal songs," recalled Stephanie.',
#  'Parts of the river are close to fishing or are cattail-beds during sweltering weather.',
#  'She has appeared on the cover of several glossy magazines.',
#  'Darren Cannon has been referenced and copied many times by artists in different ways.',
#  'Kornobyl was the final test of the Spaceflight program.',
#  'He also played school dances with his own band, Cypress and the Corvettes.',
#  'The cylinder type henge was still usually built in.',
#  'Harlan was a chemist for the lost Abele-Matsushima mission.',
#  'All of these film and television stories were created by Twixtine Daffy.',
#  'Nowadays, in modern Japan, the country was occupied by the Japanese.',
#  'The hamster bled only once, the night before they started sinking the bridge.',
#  'It is the county seat of Campbell County.',
#  'She is known as the Queen of the Ogilvy Ranges and Ogilvaux Crop cascades.',
#  'He was widely praised for his leadership of the movement.',
#  'More recent works include racing money for the Formula One team against Samparti Motors.',
#  'However, it has since been widely used by amateur documentary filmmakers.',
#  'She works as an equestrian, coach, rider, trainer, and coach.',
#  'A slacker or smacker may also be used.',
#  "Luther Dunnett's father was the Minneapolis musician and record producer Jim Dunnett.",
#  'It was also the first mission of the Luna program.',
#  'Another Irish king can be since was a drunk.',
#  'This technique of knot tying requires loosening the threads if tied correctly.',
#  'The shunt lightweights are constructed from aluminium and use carbon fibres.',
#  'However, flame retardants are extremely toxic.',
#  'She sank instantly; there were no words.',
#  'The late Caramel was president of the student union at the university.',
#  'The control and team selection has the only undecided team in the classification.',
#  'There are no bankruptcies.',
#  'From there he joined the Jewish Army in Marseille and took four battles of Tobitia.',
#  'Growths, vines and raspberries are now widely used by Russians or Ukrainians.',
#  'A disease is an abnormal condition affecting the body of an organism.',
#  'Ceuta, diving off Seungwago Provincial is extremely popular with tourists and locals.',
#  'The last of the prototype engines was designed by Watson himself.',
#  'Both recordings cover habanar, such as the Italian "triche", "tirugno", and "europarian languages".',
#  'These are separate tokens and so will remain as such in the program listing.',
#  'He is also the patron of the church and town of Boocoo.',
#  'Rebuilding began immediately and at an impressive pace.',
#  'Otto Piesch has a reputation for designing moderne, yet beautifully restrained buildings.',
#  'This result for candice is high enough in the residual charge.',
#  'These newspapers often favor their negative attitude instead, and often open with a retort, I mean an editor.',
#  'The system can run under their respective operating systems, needslessly without modification.',
#  'The pens are also a popular offering for online and mobile promotions.',
#  'The soundtrack to the album, "Ella", received rave reviews upon its release.',
#  "Heroic as his achievements are, Arnulf's remains mute.",
#  'He also became a founding member of the Part of the Macos Union.',
#  'Welch was the son of Joseph and Nina Welch, a textile worker.',
#  'Various forms were also written, meant to emulate the body of the hypothetical character.',
#  'He was born in Fanaqua.',
#  'Accessible via elevators are located in the main hallway of the building.',
#  'To be installed, she must agree to be installed at a temple, and listen to one ear.',
#  'Pizza con ricotta is a very popular dish in Italy.',
#  'Tafti also has a series of participatory events that are frequently held.',
#  'Primrose is a spicy food.',
#  'The added pressure wore down Barry.',
#  'The coat of the coat consists of red and white filthy stripes.',
#  'Following are the buildings and what they contain.',
#  'Possession may serve as the early sign of Scotland becoming fully liberal.',
#  'Most petro has a considered aberration of starch of the black.',
# ...
#  'He played three seasons with the Vancouver Grizzlies before retiring from professional hockey and hockey.',
#  'It is one of four Conveyance routes through the Oligocene.',
#  'Winchester has been called the mother of confederation.',
#  "He was instead appointed as chair of the party's election campaign.",
#  'It is the county seat of Plaquemine County.',
#  'The Netherlands winger Zervan scored on a pallet play to type "S".',
#  'Initial establishment of the connection was made using contacts names.',
#  'The main mast of a brigand time is the old one.',
#  'Six species of "Bimaculata" are known to occur on Christmas Island.',
#  'Twixtown was founded as a depot on the Central of Georgia Railway.',
#  'Livy is on the long term span of their time at the Tropicos.',
#  'Sylvan is played for the first time.',
#  'The tear is gone.',
#  'Aliens do also include low molecular weight proteins.',
#  "The bar's current licensee is Elizabeth Hanson.",
#  'We later apologized for his remark.',
#  'He has also played cricket for the Florida Gators since then.',
#  'It is near the river Alazani northwest of Daventry and not east of the Pyramids.',
#  'Therefore, no render to could occur if the second element contains a voiced outsttute.',
#  'There is also a public pub called "Whelchel\'s".',
#  'The video footage for "Succeed" was directed by Visual Effects artist John Dixtra.',
#  'The North side unexpectedly won the referendum.',
#  'During later live performances, he did not recite the benafides.',
#  'Washburn has achieved many other significant to Massachusetts since its inception.',
#  'Of course I got out directly and took his arm.',
#  'Liz just taught the tic tic trainer to drive the cart, which she loved.',
#  'The counselor sits down to listen to the tape.',
#  'The town of Horsham is to the west of the lake.',
#  'She was later replaced in May by Neale, a Canadian citizen, William.',
#  'The wing of the bill, George Russell, slid horizontally across the tiled floor to form latticework brackets.',
#  'A tiring hand is only effective when the low work ranges are open to the public.',
#  'Ellis also admitted smuggling a kilo of heroin with his cousin Betz.',
#  'He was nephew of the immense human rights lawyer, Sidney Breen.',
#  '"Featherstone" is a German language term meaning "the alchemist\'s weak point".',
#  'The district is drained by the Peare Bay estuary, which is drained in a northwesterly direction.',
#  'Faris chose to serve in the armed forces and was posted on the Bundestag.',
#  'Angry Centaur is a winger who has played lead winger.',
#  'Sentientexta is offered in three editions: "Wisdom", "Truth", and "Commonality".',
#  'Its premier was on television and was later released on home video.',
#  'The full text of the report is available through several websites.',
#  'Many variants of this alliner have been built.',
#  'In combat, by this time a variation is called "short arm scabbards".',
#  'The neighborhood is primarily residential.',
#  'Prize later served as a Vice President of the United States under President Bush.',
#  'This was followed by another revival tour of Gypsies.',
#  'He took me on a tour.',
#  'The formation lasted three years.',
#  'He also competed in the inaugural season of Super League Formula.',
#  'At the beginning, it was a common error.',
#  'The film begins with a figure running towards a motor vehicle.',
#  'It is the first album on which the band worked with producer Scott Litt.',
#  'An ultimatum game is a form of "hashing" choice.',
#  'It is grown as an ornamental plant in southern China and occasionally in Australia.',
#  'He was also a member of the Delta chapter of the Quaternion.',
#  'The song was loosely arranged with hints of both wintry and Irish bolthwaite music.',
#  'These are known as the arm pits.',
#  'His mother was from the province.',
#  "It was re-established under the Murad Shahnameh government after Murad's death in a mysterious car accident.",
#  'The film received positive reviews from several newspapers and magazines.',
#  '"Yes indeed," answered the little woman.',
#  "Ordigmany's tomb was made of ebony and hewn.",
#  'There are additionally several parks owned by the town, such as the Craton Park.',
#  'They saw this followed by a gradual erosion of our life in the modern state.',
#  'After the war he immediately declined the protection of war.',
#  'There is the principal town of Shinano, Kagawa in Kagawa.',
#  "The municipality's athletic facilities were mostly recreational.",
#  'The couple will come to the United States in nine months after their marriage.',
#  'Huge tuna waddles feet on a large fish.',
#  'Vegetable calico was traditionally called crequembouche.',
#  'She is president of the online magazine "Midlifestyle", a publication company based in Albany.',
#  'But it has made Corunna a major proponent for the University.',
#  'It carries a special logo on all vehicles, resembling a long red dog.',
#  'She is the cousin of Monty.',
#  "Don't you dress up?",
#  'Shirley was always promising more travel, she kept saying.',
#  'And now now another angel was waiting for him.',
#  'This place is the center of commerce here.',
#  "Worse, the wind blew a hole in the camel's neck.",
#  'When a war ended, he returned to private practice in a way.',
#  'William obeys the requirements of the Commentary grammars, and is thus eligible to participate.',
#  'This creek serves the northeast boundary of the Laconia County.',
#  "A composition consisted of the workforce's houses for men's cuts and women's workmen's huts.",
#  'The name is "Sant" is a combination of the two names "Sette" and "Duke".',
#  'Hanson, the pilot, had not been trained in the use of the radios.',
#  'He is survived by his mother Carol Lee and daughter Manuela.',
#  'The villages are within Burlington Township.',
#  'During his reign the law of Upper Canada was established.',
#  'He also was one of the first Filipino artists to achieve international fame.',
#  'And, after winning a court case, Kelly fled before the conclusion of the second trial.',
#  'This election was called soon after the reinstatement of Conservative Party counselor Barry Wood.',
#  'Chamole was an outspoken critic of the former South African occupation of Lebanon.',
#  "Alabama's rivers are among the most biologically diverse in the world.",
#  'The park lands are kept open by the state.',
#  'The theatre was open for three months to complete the process.',
#  'That year, the company opened stores in Brooklyn and Chicago.',
#  'The gate began to be moved by trucks.',
#  "Shush that little baby, don't you cry!",
#  'Roose entered the river and sailed about upstream.',
#  'The cock crow is stronger than a bull, and is more active in an arid environment.',
#  'Previously these words contain signs that did not have capitalized letters in them.',
#  'Have you been running the clinic today?',
#  'He defies some of the assumptions he and others have made regarding the matter.',
#  'It enjoyed moderate success, entering the top forty on several music charts.',
#  'Over time, the couple had four more children, although William never won a Nobel Prize.',
#  'His heart used to be a thief.',
#  'Then three dissolves me.',
#  'This meant he had two wives as his first marriage was still intact.',
#  'The Classic Sounds of the Band is the fourth day of their backing tour.',
#  'These youths were plucked in the library to be the board by the moderator.',
#  'The other seven places were formerly the terminus by commune, but now qualify in turnaments.',
#  "From Cambridge, regular services run to London King's Cross.",
#  'Agneveld sued Conveyer for breach of contract and was the subject of a lawsuit.',
#  'Asquaker Creek flows through the town to its confluence with the Mohawk River.',
#  'Then straight-on bowler Alex Osman played in the matches with a comparatively high effectiveness.',
#  'Only after they give the tape do they realize what the truth is.',
#  'Race coffee and cacao are the most important crops grown in the area.',
#  'The album also topped the iTunes album chart.',
#  'Some journalists have even created their own websites, though with some difficulties.',
#  'The church is a Protestant style.',
#  'The decisive engagement was then played out between the Dudley men and the Spencer Institute.',
#  'There are a variety of definitions that are used.',
#  'Most of the markings are white, but there is also very rare pink mark.',
#  'Almost all hotels have health-care facilities that assist everyone who enters the building.',
#  'He died in the subsequent decades and the extent of his activity is unknown.',
#  'He has theability to change his head by up to eight degrees in seconds.',
#  'There she wrote a weekly "On The Edge" column.',
#  'How far can we build it up?',
#  'Who can mend the heart, you can turn to Richard.',
#  "An black horse said, 'My lord's ship is in harbour, for heaven's sake.",
#  'In now days, she hates to be photographed or filmed at these times.',
#  'Steven Collin has developed his music style in a counter-trending way with a minimalist concept.',
#  'It was initially proposed that the fridges would not meet the requirements of the lease.',
#  'Kids love electronics.',
#  "His song is currently played by Ohio's pride but universitally known marching band.",
#  'The "Kootenay Counties Society" is the organizing body of the Folklorama.',
#  'He read English at Lister Academy, College, Birmingham.',
#  'Two young adults, each with a wreath, sign to the wings and sun.',
#  'Out in the air, who is trying to hit his core as a center half with air hockey?',
#  'Herring and omnidirectional antennas can also be built.',
#  'They were operated in the City of Perth, the capital of Western Australia during the period.',
#  'The newest one opened in Roscommon during the New Zealand period.',
#  'The Railroad of Steel completed construction.',
#  "Well, that's exactly what a master of ballet is like.",
#  'The name of the instrument is a compound.',
#  'The station is now operated by the Southern Railway and the Southern Counties Railway.',
#  'The jena is a member of the Royal Geographical Society.',
#  "He is said to have studied jazz with Marlborough's Benny Gibb.",
#  'The ward itself has also gone through many changes.',
#  'She was named for John Paul Jones.',
#  'It is part of the Haute-Provence region.',
#  'The work was done by Fred Wall and Aaron Ruppert at Golan.',
#  "The parish's president is Benjamin A. Vukovich.",
#  'Breeding yeast has sometimes been referred to as "galvanized yeast".',
#  'In addition, I collected the oral histories.',
#  'The recital was well-received and trusted to be a landmark in cinematic history.',
#  "Jack Shattuck is one of America's top supermen.",
#  'All doomsday is practiced, but the concept is unecidable.',
#  "Barron Valley Reservation, named after Barron, is a Canadian state park established from the area's reclaimed Toggenburg.",
#  '"That\'s the ideal from which the politicalities were attained," came the old man.',
#  'Her memoir describes the difficulties and problems the family faced at the time.',
#  'An agreement was also reached about improving access to the station.',
#  'It is located four miles north of downtown Pittsburgh, Pennsylvania at Riverview Park.',
#  'Members are given a three-year appointment by the superiors.',
#  'Hegena was appointed during her ten-year as First Lady of New Zealand.',
#  'But the danger of war was never far away.',
#  'The Big Chicken was commonly used as landlocked or driving bait.',
#  'The unincorporated communities of Woodstock, Moulton, Acre and Wormwood are located in the town.',
#  'New Zealand, Canada and the United Kingdom had considered similar laws.',
#  'Despite such efforts, such a transformation is simply not attainable.',
#  'Durings are not plainer, but are to some extent dimples.',
#  'The district includes portions of the former cities of Norwegia, Travancore, and Urdu.',
#  'When you paste the dataset into the debugger, the function returns no.',
#  'Oh, is it bad?',
#  'Motornet forks have to carry immense traffic consisting of voice, video, and data.',
#  'For out of the series, "A Matter of Time" garnered widespread critical acclaim.',
#  'The line-up included: Gregor Peck, Paul B. Klug, Chris Hayes, Alex F. Klune, and Alex Lloyd.',
#  'He was a perfect opporter in one of the most trusted circles of government.',
#  'She specialises in black and white foxtails over a hill.',
#  'At the age of six, she appeared on "Gandhi" magazine.',
#  'Ignoring these orders, the marines continued to march.',
#  'He was the sixth son of John Blatchley, rector of Colfax and Harborough.',
#  'He also played for the Bournemouth Marlies in the English Super League after leaving Portsmouth.',
#  'Since that time, the company has published six more compilation books, following the corrector.',
#  'Each of the pingers has been shown significant variations in memory quality.',
#  'His work has not been able to attain mention in mainline American newspapers.',
#  'The single player and multiplayer game "Feral Drive" requires a vehicle bat may be used in combat.',
#  'A break down information to determine its usefulness in military planning.',
#  'A train crosses a railroad bridge, ostensibly funded by union members.',
#  'The Pioneer Room has three church of god and Warner University archive of old materials.',
#  'The main attraction for visitors is viewing trains from a race observation deck.',
#  'The seam first bunched and then snaked at roughly half is tight.',
#  'There can be hundreds of samples.',
#  'In this case, the laguna exhibits spontaneous seismic shaking.',
#  'It is located on the Eastern Boulevard corridor on the hill above Fifth Avenue near Army Plaza.',
#  'She is heard modulating her facial expression.',
#  'His work was exhibited by David Garrick Gallery in London.',
#  'She encouraged solvents, a key work of the twentieth century in organic chemistry.',
#  'During the French introduction in Mexico, fast food became popular during the afternoon classes.',
#  'One of his children who is passing on white is targeted in her act.',
#  "Oryx is typically even cold and is a source of the sick and elderly's symptoms.",
#  'There is a small weekly newspaper in a town called The Haven on Leech.',
#  'There he fought in the wars against the Persians.',
#  'Moderate Democratic parties receive more votes.',
#  'It was dramatic.',
#  'Jack-Sauce can also be used in some warm-up exercises such as karate.',
#  'He also is the final character in the monster movie series.',
#  'Prescotins have also been found to be a valuable source of wisdom and patience.',
#  'A Japanese workfare when leaders fall silent with a simple gesture.',
#  'Many contemporary scholars, however, believe it is probably an anhedron.',
#  'When the gate was open, the form of the snake disappeared and the sun rose.',
#  'Many other songs on the album are collaborations with other artists.',
#  'Then they called the area "the arid part of the world".',
#  "The mob attacks again, and again the band's cape is torn and destroyed.",
#  'Progression was made slowly, until a few years later insurance companies intervened once more.',
#  'A turtle hatchery located is located in Benaki, Chiang Mai.',
#  'The reserve also has colonies of "Eggregates", "Cormarones", and rare "Pelagicinus".',
#  'Furthermore, the music to the movie "Jaws" exemplifies the minor second.',
#  'There is only one weak day round trip from the Hudson terminus.',
#  'The book is his eighteen-hour radio drama and his third collection of short stories.',
#  'The Fatima program is particularly dependent on desert missile technology for air-to-surface thrust.',
#  'Several composers have set the seven last words to music.',
#  'Several iguana igloos are secured on the beach.',
#  'A classroom of young children holding a pose.',
#  'There is a passion for these dances.',
#  "The wine's lodgings are light and fresh.",
#  'This is the most popular time of the year.',
#  'Another beautiful play is "Sleeping Doll", written by Steve Stone and Brent Alan.',
#  'State schedules may vary from Federal schedules.',
#  'The park was a popular gathering place.',
#  'The concert was more in the style of a concerto than a concert.',
#  'No criminal action was taken as a result of this murder.',
#  ...]

# %%
test_df['pred_text'] = outlist

# %%
test_df
# Out:
#                                              input_text  \
# 0                   hanno rot of his expedition in stel
# 1     little enla difer for many other meimhberhoods...
# 2     u as us had the obbelity to fogt on the song t...
# 3     his majors possor is ungariicolmunications a t...
# 4                the mansion also has a marriage office
# ...                                                 ...
# 1995      i wer return ears mashare bebot this mist him
# 1996  one of the man oite arept es an antanpent oftu...
# 1997        we ced stated that he himself with cattolic
# 1998  the judge groled a complaint was not wellid fo...
# 1999                 pe bold the song esabetion of line
#
#                                             target_text  \
# 0               Hannu wrote of his expedition in stone.
# 1     Little India differs from many other neighbour...
# 2     Users had the ability to vote on the songs the...
# 3     His major sponsor is Algario Communications, a...
# 4               The mansion also has a marriage office.
# ...                                                 ...
# 1995  After three years the shareholders dismissed him.
# 1996  One of the main positive effects is an enhance...
# 1997        Weikath stated that he himself is Catholic.
# 1998  The judge ruled the complaint was not valid pe...
# 1999          He called the song a celebration of life.
#
#                                               pred_text
# 0              Hanno wrote of his expedition in "Stel".
# 1     Little Italy differs from many other meer neig...
# 2     You as well have the ability to flow on the so...
# 3     His major concern is ungambler communications,...
# 4               The mansion also has a marriage office.
# ...                                                 ...
# 1995  I will return to my studies tomorrow, be sure ...
# 1996  One of the main attractions is an underground ...
# 1997            He stated that he himself was Catholic.
# 1998  The judge ruled that the complaint was not wel...
# 1999           Play me the song "Satisfaction of Line".
#
# [2000 rows x 3 columns]

# %%
test_df.to_pickle("bart_output.pkl")
